# %% [markdown]
# ## Training the tokenizer
# This notebook is an example on how to use the tokenizer
#
# first we have to import the tokenizer, the tokenizer user a BPE algorithm and is inside the class BPETokenizer
#
# You can train the algorithm in multiple documents or using a single text file.
# In this exemple we are going to use multiple documents
#
# You also have to decide the number of target tokens. for this exemple we are using 5000

# %%
from BPE import BPETokenizer
import pickle

tokenizer = BPETokenizer()
tokenizer.tokenizer_fit_multidocs(5000, 'corpus')
# Out:
# Opening files text
# /home/pedro/Desktop/Pastas/UNB/Doutorado/NLP/nlp/BPE/BPE.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Applying regex rules on files text...
# Selecting tokens
#   0%|          | 0/10000 [00:00<?, ?it/s]
# training...
#   0%|          | 0/4744 [00:00<?, ?it/s]
# pair (32, 100) -> 256
# pair (32, 101) -> 257
# pair (114, 97) -> 258
# pair (32, 97) -> 259
# pair (256, 101) -> 260
# pair (111, 115) -> 261
# pair (32, 112) -> 262
# pair (110, 116) -> 263
# pair (32, 99) -> 264
# pair (101, 115) -> 265
# pair (111, 114) -> 266
# pair (101, 114) -> 267
# pair (97, 115) -> 268
# pair (32, 115) -> 269
# pair (105, 97) -> 270
# pair (105, 115) -> 271
# pair (97, 100) -> 272
# pair (105, 110) -> 273
# pair (195, 163) -> 274
# pair (114, 101) -> 275
# pair (274, 111) -> 276
# pair (109, 97) -> 277
# pair (105, 99) -> 278
# pair (32, 111) -> 279
# pair (264, 111) -> 280
# pair (116, 97) -> 281
# pair (195, 167) -> 282
# pair (32, 110) -> 283
# pair (114, 111) -> 284
# pair (109, 101) -> 285
# pair (113, 117) -> 286
# pair (105, 100) -> 287
# pair (32, 102) -> 288
# pair (97, 114) -> 289
# pair (110, 100) -> 290
# pair (195, 169) -> 291
# pair (116, 101) -> 292
# pair (97, 108) -> 293
# pair (32, 49) -> 294
# pair (32, 67) -> 295
# pair (105, 111) -> 296
# pair (32, 65) -> 297
# pair (256, 111) -> 298
# pair (32, 124) -> 299
# pair (195, 173) -> 300
# pair (32, 117) -> 301
# pair (116, 111) -> 302
# pair (32, 286) -> 303
# pair (256, 97) -> 304
# pair (195, 161) -> 305
# pair (280, 109) -> 306
# pair (32, 109) -> 307
# pair (61, 61) -> 308
# pair (32, 83) -> 309
# pair (101, 108) -> 310
# pair (282, 276) -> 311
# pair (263, 101) -> 312
# pair (32, 80) -> 313
# pair (257, 109) -> 314
# pair (114, 105) -> 315
# pair (105, 108) -> 316
# pair (269, 101) -> 317
# pair (111, 108) -> 318
# pair (32, 42) -> 319
# pair (97, 110) -> 320
# pair (32, 77) -> 321
# pair (32, 116) -> 322
# pair (32, 69) -> 323
# pair (303, 101) -> 324
# pair (101, 110) -> 325
# pair (117, 108) -> 326
# pair (32, 50) -> 327
# pair (257, 115) -> 328
# pair (32, 40) -> 329
# pair (97, 258) -> 330
# pair (32, 275) -> 331
# pair (111, 110) -> 332
# pair (32, 118) -> 333
# pair (32, 108) -> 334
# pair (101, 105) -> 335
# pair (299, 124) -> 336
# pair (195, 179) -> 337
# pair (116, 105) -> 338
# pair (116, 117) -> 339
# pair (294, 57) -> 340
# pair (32, 66) -> 341
# pair (103, 117) -> 342
# pair (32, 98) -> 343
# pair (32, 308) -> 344
# pair (101, 109) -> 345
# pair (110, 99) -> 346
# pair (283, 111) -> 347
# pair (32, 277) -> 348
# pair (32, 79) -> 349
# pair (278, 97) -> 350
# pair (272, 111) -> 351
# pair (290, 111) -> 352
# pair (32, 82) -> 353
# pair (104, 97) -> 354
# pair (111, 117) -> 355
# pair (114, 265) -> 356
# pair (32, 76) -> 357
# pair (32, 68) -> 358
# pair (32, 70) -> 359
# pair (32, 78) -> 360
# pair (32, 84) -> 361
# pair (32, 273) -> 362
# pair (263, 111) -> 363
# pair (110, 115) -> 364
# pair (100, 111) -> 365
# pair (117, 115) -> 366
# pair (301, 109) -> 367
# pair (283, 97) -> 368
# pair (32, 73) -> 369
# pair (32, 103) -> 370
# pair (301, 277) -> 371
# pair (327, 48) -> 372
# pair (118, 97) -> 373
# pair (108, 101) -> 374
# pair (262, 330) -> 375
# pair (109, 112) -> 376
# pair (262, 266) -> 377
# pair (32, 71) -> 378
# pair (287, 272) -> 379
# pair (195, 170) -> 380
# pair (101, 263) -> 381
# pair (101, 99) -> 382
# pair (32, 291) -> 383
# pair (269, 117) -> 384
# pair (195, 181) -> 385
# pair (111, 99) -> 386
# pair (288, 111) -> 387
# pair (385, 265) -> 388
# pair (115, 101) -> 389
# pair (285, 312) -> 390
# pair (32, 105) -> 391
# pair (258, 115) -> 392
# pair (226, 128) -> 393
# pair (272, 97) -> 394
# pair (109, 98) -> 395
# pair (108, 97) -> 396
# pair (105, 103) -> 397
# pair (271, 116) -> 398
# pair (262, 284) -> 399
# pair (104, 111) -> 400
# pair (32, 195) -> 401
# pair (32, 261) -> 402
# pair (110, 97) -> 403
# pair (100, 101) -> 404
# pair (259, 115) -> 405
# pair (379, 101) -> 406
# pair (105, 118) -> 407
# pair (32, 74) -> 408
# pair (105, 116) -> 409
# pair (117, 110) -> 410
# pair (262, 111) -> 411
# pair (32, 292) -> 412
# pair (257, 120) -> 413
# pair (100, 97) -> 414
# pair (260, 115) -> 415
# pair (105, 122) -> 416
# pair (279, 117) -> 417
# pair (109, 111) -> 418
# pair (114, 270) -> 419
# pair (101, 258) -> 420
# pair (110, 111) -> 421
# pair (306, 111) -> 422
# pair (295, 97) -> 423
# pair (32, 86) -> 424
# pair (256, 261) -> 425
# pair (97, 311) -> 426
# pair (32, 72) -> 427
# pair (32, 393) -> 428
# pair (262, 310) -> 429
# pair (278, 111) -> 430
# pair (32, 106) -> 431
# pair (259, 108) -> 432
# pair (115, 111) -> 433
# pair (387, 105) -> 434
# pair (287, 111) -> 435
# pair (282, 388) -> 436
# pair (195, 186) -> 437
# pair (97, 99) -> 438
# pair (296, 110) -> 439
# pair (114, 117) -> 440
# pair (105, 281) -> 441
# pair (114, 261) -> 442
# pair (105, 112) -> 443
# pair (97, 116) -> 444
# pair (285, 363) -> 445
# pair (264, 97) -> 446
# pair (99, 111) -> 447
# pair (32, 34) -> 448
# pair (259, 112) -> 449
# pair (323, 115) -> 450
# pair (32, 61) -> 451
# pair (272, 261) -> 452
# pair (114, 296) -> 453
# pair (328, 116) -> 454
# pair (48, 48) -> 455
# pair (32, 285) -> 456
# pair (105, 109) -> 457
# pair (291, 109) -> 458
# pair (346, 270) -> 459
# pair (32, 104) -> 460
# pair (32, 281) -> 461
# pair (111, 103) -> 462
# pair (258, 109) -> 463
# pair (266, 270) -> 464
# pair (32, 85) -> 465
# pair (118, 101) -> 466
# pair (344, 61) -> 467
# pair (290, 101) -> 468
# pair (32, 51) -> 469
# pair (266, 265) -> 470
# pair (104, 101) -> 471
# pair (348, 271) -> 472
# pair (99, 97) -> 473
# pair (259, 111) -> 474
# pair (105, 102) -> 475
# pair (105, 114) -> 476
# pair (99, 101) -> 477
# pair (32, 45) -> 478
# pair (116, 267) -> 479
# pair (257, 263) -> 480
# pair (287, 97) -> 481
# pair (428, 148) -> 482
# pair (262, 289) -> 483
# pair (269, 267) -> 484
# pair (282, 97) -> 485
# pair (195, 162) -> 486
# pair (263, 265) -> 487
# pair (270, 108) -> 488
# pair (401, 160) -> 489
# pair (267, 115) -> 490
# pair (273, 97) -> 491
# pair (335, 284) -> 492
# pair (110, 261) -> 493
# pair (280, 364) -> 494
# pair (99, 318) -> 495
# pair (115, 97) -> 496
# pair (271, 281) -> 497
# pair (111, 98) -> 498
# pair (285, 263) -> 499
# pair (259, 116) -> 500
# pair (256, 268) -> 501
# pair (117, 114) -> 502
# pair (41, 46) -> 503
# pair (112, 111) -> 504
# pair (340, 57) -> 505
# pair (100, 117) -> 506
# pair (339, 258) -> 507
# pair (322, 258) -> 508
# pair (41, 44) -> 509
# pair (295, 111) -> 510
# pair (105, 268) -> 511
# pair (288, 266) -> 512
# pair (384, 97) -> 513
# pair (338, 118) -> 514
# pair (103, 111) -> 515
# pair (372, 48) -> 516
# pair (322, 267) -> 517
# pair (280, 110) -> 518
# pair (32, 302) -> 519
# pair (101, 100) -> 520
# pair (116, 261) -> 521
# pair (97, 109) -> 522
# pair (280, 263) -> 523
# pair (283, 276) -> 524
# pair (323, 109) -> 525
# pair (262, 267) -> 526
# pair (372, 49) -> 527
# pair (292, 103) -> 528
# pair (300, 115) -> 529
# pair (111, 118) -> 530
# pair (32, 52) -> 531
# pair (307, 117) -> 532
# pair (101, 312) -> 533
# pair (105, 302) -> 534
# pair (262, 114) -> 535
# pair (105, 258) -> 536
# pair (105, 98) -> 537
# pair (116, 278) -> 538
# pair (335, 258) -> 539
# pair (70, 65) -> 540
# pair (262, 97) -> 541
# pair (528, 464) -> 542
# pair (263, 267) -> 543
# pair (49, 57) -> 544
# pair (103, 105) -> 545
# pair (101, 116) -> 546
# pair (380, 459) -> 547
# pair (108, 117) -> 548
# pair (306, 112) -> 549
# pair (395, 458) -> 550
# pair (439, 293) -> 551
# pair (328, 112) -> 552
# pair (259, 114) -> 553
# pair (262, 315) -> 554
# pair (108, 111) -> 555
# pair (291, 99) -> 556
# pair (392, 316) -> 557
# pair (423, 542) -> 558
# pair (290, 97) -> 559
# pair (195, 180) -> 560
# pair (32, 305) -> 561
# pair (97, 271) -> 562
# pair (317, 117) -> 563
# pair (100, 261) -> 564
# pair (117, 116) -> 565
# pair (109, 273) -> 566
# pair (272, 268) -> 567
# pair (326, 111) -> 568
# pair (32, 356) -> 569
# pair (294, 56) -> 570
# pair (105, 261) -> 571
# pair (461, 550) -> 572
# pair (105, 266) -> 573
# pair (103, 97) -> 574
# pair (32, 53) -> 575
# pair (353, 101) -> 576
# pair (297, 108) -> 577
# pair (117, 258) -> 578
# pair (417, 116) -> 579
# pair (32, 75) -> 580
# pair (32, 87) -> 581
# pair (112, 326) -> 582
# pair (117, 109) -> 583
# pair (410, 278) -> 584
# pair (281, 108) -> 585
# pair (360, 111) -> 586
# pair (112, 97) -> 587
# pair (269, 276) -> 588
# pair (259, 99) -> 589
# pair (105, 311) -> 590
# pair (370, 258) -> 591
# pair (101, 122) -> 592
# pair (98, 108) -> 593
# pair (309, 97) -> 594
# pair (480, 275) -> 595
# pair (32, 266) -> 596
# pair (118, 310) -> 597
# pair (429, 97) -> 598
# pair (116, 350) -> 599
# pair (380, 115) -> 600
# pair (554, 285) -> 601
# pair (299, 45) -> 602
# pair (300, 112) -> 603
# pair (97, 352) -> 604
# pair (495, 266) -> 605
# pair (103, 605) -> 606
# pair (262, 261) -> 607
# pair (61, 35) -> 608
# pair (343, 606) -> 609
# pair (305, 453) -> 610
# pair (328, 281) -> 611
# pair (429, 111) -> 612
# pair (307, 111) -> 613
# pair (286, 101) -> 614
# pair (391, 376) -> 615
# pair (50, 48) -> 616
# pair (279, 102) -> 617
# pair (263, 97) -> 618
# pair (273, 111) -> 619
# pair (268, 115) -> 620
# pair (32, 54) -> 621
# pair (99, 296) -> 622
# pair (259, 98) -> 623
# pair (313, 97) -> 624
# pair (266, 292) -> 625
# pair (321, 289) -> 626
# pair (257, 110) -> 627
# pair (273, 103) -> 628
# pair (287, 261) -> 629
# pair (277, 110) -> 630
# pair (317, 342) -> 631
# pair (105, 120) -> 632
# pair (305, 315) -> 633
# pair (269, 498) -> 634
# pair (465, 110) -> 635
# pair (265, 115) -> 636
# pair (262, 275) -> 637
# pair (103, 258) -> 638
# pair (265, 433) -> 639
# pair (32, 354) -> 640
# pair (105, 445) -> 641
# pair (257, 374) -> 642
# pair (99, 104) -> 643
# pair (450, 116) -> 644
# pair (313, 266) -> 645
# pair (265, 116) -> 646
# pair (288, 117) -> 647
# pair (325, 115) -> 648
# pair (297, 115) -> 649
# pair (32, 56) -> 650
# pair (273, 99) -> 651
# pair (273, 354) -> 652
# pair (256, 271) -> 653
# pair (106, 97) -> 654
# pair (338, 339) -> 655
# pair (288, 97) -> 656
# pair (278, 261) -> 657
# pair (540, 540) -> 658
# pair (279, 98) -> 659
# pair (348, 114) -> 660
# pair (101, 117) -> 661
# pair (118, 318) -> 662
# pair (118, 267) -> 663
# pair (105, 275) -> 664
# pair (584, 603) -> 665
# pair (103, 345) -> 666
# pair (341, 557) -> 667
# pair (110, 101) -> 668
# pair (105, 277) -> 669
# pair (112, 356) -> 670
# pair (109, 268) -> 671
# pair (258, 108) -> 672
# pair (337, 115) -> 673
# pair (32, 55) -> 674
# pair (349, 115) -> 675
# pair (271, 292) -> 676
# pair (411, 582) -> 677
# pair (112, 261) -> 678
# pair (309, 276) -> 679
# pair (100, 267) -> 680
# pair (405, 115) -> 681
# pair (112, 267) -> 682
# pair (258, 110) -> 683
# pair (259, 493) -> 684
# pair (343, 97) -> 685
# pair (257, 258) -> 686
# pair (342, 265) -> 687
# pair (545, 276) -> 688
# pair (111, 109) -> 689
# pair (381, 265) -> 690
# pair (340, 56) -> 691
# pair (307, 265) -> 692
# pair (407, 490) -> 693
# pair (267, 258) -> 694
# pair (307, 268) -> 695
# pair (105, 284) -> 696
# pair (116, 268) -> 697
# pair (319, 42) -> 698
# pair (266, 275) -> 699
# pair (264, 406) -> 700
# pair (272, 101) -> 701
# pair (99, 332) -> 702
# pair (32, 48) -> 703
# pair (307, 316) -> 704
# pair (102, 266) -> 705
# pair (101, 103) -> 706
# pair (116, 266) -> 707
# pair (288, 316) -> 708
# pair (293, 416) -> 709
# pair (278, 268) -> 710
# pair (391, 543) -> 711
# pair (338, 373) -> 712
# pair (112, 101) -> 713
# pair (105, 292) -> 714
# pair (104, 382) -> 715
# pair (257, 108) -> 716
# pair (282, 111) -> 717
# pair (330, 109) -> 718
# pair (379, 265) -> 719
# pair (499, 261) -> 720
# pair (264, 289) -> 721
# pair (118, 111) -> 722
# pair (32, 57) -> 723
# pair (259, 110) -> 724
# pair (98, 111) -> 725
# pair (194, 186) -> 726
# pair (258, 346) -> 727
# pair (105, 117) -> 728
# pair (262, 356) -> 729
# pair (512, 277) -> 730
# pair (98, 284) -> 731
# pair (398, 337) -> 732
# pair (358, 101) -> 733
# pair (100, 268) -> 734
# pair (295, 332) -> 735
# pair (99, 270) -> 736
# pair (283, 268) -> 737
# pair (272, 266) -> 738
# pair (32, 284) -> 739
# pair (109, 267) -> 740
# pair (321, 97) -> 741
# pair (309, 386) -> 742
# pair (265, 292) -> 743
# pair (634, 275) -> 744
# pair (114, 305) -> 745
# pair (78, 69) -> 746
# pair (98, 97) -> 747
# pair (115, 116) -> 748
# pair (291, 114) -> 749
# pair (271, 418) -> 750
# pair (342, 97) -> 751
# pair (665, 296) -> 752
# pair (108, 270) -> 753
# pair (262, 318) -> 754
# pair (264, 268) -> 755
# pair (32, 88) -> 756
# pair (328, 99) -> 757
# pair (106, 101) -> 758
# pair (309, 101) -> 759
# pair (387, 463) -> 760
# pair (340, 55) -> 761
# pair (283, 261) -> 762
# pair (322, 266) -> 763
# pair (100, 270) -> 764
# pair (320, 111) -> 765
# pair (360, 97) -> 766
# pair (560, 110) -> 767
# pair (412, 376) -> 768
# pair (116, 265) -> 769
# pair (264, 108) -> 770
# pair (535, 651) -> 771
# pair (115, 117) -> 772
# pair (297, 114) -> 773
# pair (102, 267) -> 774
# pair (500, 291) -> 775
# pair (97, 363) -> 776
# pair (105, 101) -> 777
# pair (399, 506) -> 778
# pair (112, 266) -> 779
# pair (103, 101) -> 780
# pair (335, 302) -> 781
# pair (65, 82) -> 782
# pair (362, 99) -> 783
# pair (275, 97) -> 784
# pair (118, 270) -> 785
# pair (315, 116) -> 786
# pair (486, 110) -> 787
# pair (633, 261) -> 788
# pair (295, 104) -> 789
# pair (334, 386) -> 790
# pair (111, 263) -> 791
# pair (259, 100) -> 792
# pair (378, 117) -> 793
# pair (273, 365) -> 794
# pair (280, 346) -> 795
# pair (300, 110) -> 796
# pair (102, 270) -> 797
# pair (266, 284) -> 798
# pair (332, 97) -> 799
# pair (268, 101) -> 800
# pair (273, 293) -> 801
# pair (116, 430) -> 802
# pair (320, 97) -> 803
# pair (98, 101) -> 804
# pair (341, 97) -> 805
# pair (530, 267) -> 806
# pair (279, 99) -> 807
# pair (104, 261) -> 808
# pair (117, 284) -> 809
# pair (258, 311) -> 810
# pair (333, 592) -> 811
# pair (340, 54) -> 812
# pair (640, 98) -> 813
# pair (393, 147) -> 814
# pair (317, 366) -> 815
# pair (73, 746) -> 816
# pair (271, 115) -> 817
# pair (281, 114) -> 818
# pair (32, 400) -> 819
# pair (325, 268) -> 820
# pair (294, 53) -> 821
# pair (309, 117) -> 822
# pair (264, 266) -> 823
# pair (257, 346) -> 824
# pair (362, 100) -> 825
# pair (397, 97) -> 826
# pair (264, 267) -> 827
# pair (443, 293) -> 828
# pair (32, 81) -> 829
# pair (34, 46) -> 830
# pair (116, 316) -> 831
# pair (307, 752) -> 832
# pair (291, 115) -> 833
# pair (288, 275) -> 834
# pair (32, 258) -> 835
# pair (347, 285) -> 836
# pair (398, 268) -> 837
# pair (742, 798) -> 838
# pair (295, 289) -> 839
# pair (357, 816) -> 840
# pair (840, 782) -> 841
# pair (34, 44) -> 842
# pair (578, 312) -> 843
# pair (514, 111) -> 844
# pair (294, 48) -> 845
# pair (408, 111) -> 846
# pair (264, 419) -> 847
# pair (432, 342) -> 848
# pair (98, 267) -> 849
# pair (50, 455) -> 850
# pair (287, 268) -> 851
# pair (103, 275) -> 852
# pair (334, 101) -> 853
# pair (98, 293) -> 854
# pair (269, 97) -> 855
# pair (541, 529) -> 856
# pair (289, 270) -> 857
# pair (282, 268) -> 858
# pair (289, 265) -> 859
# pair (483, 292) -> 860
# pair (437, 593) -> 861
# pair (109, 261) -> 862
# pair (313, 289) -> 863
# pair (409, 261) -> 864
# pair (384, 98) -> 865
# pair (108, 265) -> 866
# pair (294, 55) -> 867
# pair (100, 296) -> 868
# pair (331, 688) -> 869
# pair (303, 293) -> 870
# pair (317, 352) -> 871
# pair (99, 551) -> 872
# pair (508, 364) -> 873
# pair (348, 573) -> 874
# pair (273, 101) -> 875
# pair (273, 414) -> 876
# pair (420, 108) -> 877
# pair (353, 296) -> 878
# pair (100, 345) -> 879
# pair (110, 103) -> 880
# pair (518, 715) -> 881
# pair (354, 109) -> 882
# pair (259, 421) -> 883
# pair (401, 186) -> 884
# pair (337, 112) -> 885
# pair (116, 258) -> 886
# pair (98, 117) -> 887
# pair (313, 111) -> 888
# pair (279, 468) -> 889
# pair (104, 268) -> 890
# pair (289, 100) -> 891
# pair (829, 117) -> 892
# pair (331, 396) -> 893
# pair (446, 112) -> 894
# pair (310, 97) -> 895
# pair (103, 261) -> 896
# pair (118, 105) -> 897
# pair (256, 664) -> 898
# pair (269, 105) -> 899
# pair (305, 115) -> 900
# pair (353, 111) -> 901
# pair (272, 470) -> 902
# pair (412, 109) -> 903
# pair (357, 97) -> 904
# pair (259, 117) -> 905
# pair (754, 300) -> 906
# pair (118, 293) -> 907
# pair (475, 278) -> 908
# pair (362, 115) -> 909
# pair (561, 784) -> 910
# pair (321, 111) -> 911
# pair (103, 320) -> 912
# pair (334, 117) -> 913
# pair (277, 114) -> 914
# pair (333, 267) -> 915
# pair (294, 54) -> 916
# pair (373, 109) -> 917
# pair (397, 110) -> 918
# pair (475, 350) -> 919
# pair (116, 284) -> 920
# pair (107, 109) -> 921
# pair (334, 332) -> 922
# pair (732, 419) -> 923
# pair (110, 268) -> 924
# pair (361, 471) -> 925
# pair (345, 731) -> 926
# pair (591, 468) -> 927
# pair (280, 108) -> 928
# pair (415, 325) -> 929
# pair (117, 290) -> 930
# pair (116, 104) -> 931
# pair (411, 404) -> 932
# pair (384, 268) -> 933
# pair (294, 50) -> 934
# pair (428, 147) -> 935
# pair (510, 109) -> 936
# pair (122, 97) -> 937
# pair (117, 277) -> 938
# pair (116, 440) -> 939
# pair (437, 115) -> 940
# pair (294, 51) -> 941
# pair (386, 97) -> 942
# pair (259, 261) -> 943
# pair (303, 604) -> 944
# pair (300, 99) -> 945
# pair (49, 56) -> 946
# pair (258, 414) -> 947
# pair (103, 289) -> 948
# pair (656, 122) -> 949
# pair (340, 53) -> 950
# pair (454, 305) -> 951
# pair (117, 112) -> 952
# pair (579, 442) -> 953
# pair (256, 398) -> 954
# pair (692, 418) -> 955
# pair (504, 271) -> 956
# pair (291, 315) -> 957
# pair (331, 103) -> 958
# pair (505, 57) -> 959
# pair (259, 263) -> 960
# pair (294, 52) -> 961
# pair (295, 268) -> 962
# pair (265, 97) -> 963
# pair (523, 258) -> 964
# pair (287, 420) -> 965
# pair (339, 293) -> 966
# pair (101, 290) -> 967
# pair (601, 696) -> 968
# pair (416, 426) -> 969
# pair (345, 112) -> 970
# pair (320, 492) -> 971
# pair (658, 540) -> 972
# pair (273, 268) -> 973
# pair (326, 507) -> 974
# pair (370, 806) -> 975
# pair (256, 270) -> 976
# pair (346, 511) -> 977
# pair (320, 104) -> 978
# pair (300, 622) -> 979
# pair (260, 99) -> 980
# pair (313, 330) -> 981
# pair (331, 99) -> 982
# pair (269, 556) -> 983
# pair (116, 114) -> 984
# pair (118, 265) -> 985
# pair (362, 102) -> 986
# pair (98, 318) -> 987
# pair (347, 118) -> 988
# pair (357, 117) -> 989
# pair (438, 551) -> 990
# pair (677, 426) -> 991
# pair (538, 268) -> 992
# pair (271, 276) -> 993
# pair (106, 117) -> 994
# pair (316, 97) -> 995
# pair (49, 48) -> 996
# pair (343, 557) -> 997
# pair (266, 100) -> 998
# pair (305, 419) -> 999
# pair (340, 51) -> 1000
# pair (322, 471) -> 1001
# pair (73, 73) -> 1002
# pair (601, 536) -> 1003
# pair (431, 117) -> 1004
# pair (313, 284) -> 1005
# pair (552, 382) -> 1006
# pair (259, 876) -> 1007
# pair (262, 639) -> 1008
# pair (293, 97) -> 1009
# pair (325, 97) -> 1010
# pair (266, 281) -> 1011
# pair (645, 339) -> 1012
# pair (380, 109) -> 1013
# pair (348, 105) -> 1014
# pair (100, 266) -> 1015
# pair (454, 351) -> 1016
# pair (335, 442) -> 1017
# pair (326, 97) -> 1018
# pair (462, 270) -> 1019
# pair (259, 102) -> 1020
# pair (116, 351) -> 1021
# pair (298, 271) -> 1022
# pair (256, 843) -> 1023
# pair (813, 441) -> 1024
# pair (337, 108) -> 1025
# pair (768, 111) -> 1026
# pair (381, 97) -> 1027
# pair (259, 290) -> 1028
# pair (508, 854) -> 1029
# pair (97, 112) -> 1030
# pair (32, 90) -> 1031
# pair (297, 112) -> 1032
# pair (117, 293) -> 1033
# pair (260, 122) -> 1034
# pair (278, 488) -> 1035
# pair (338, 114) -> 1036
# pair (280, 285) -> 1037
# pair (104, 266) -> 1038
# pair (103, 293) -> 1039
# pair (441, 108) -> 1040
# pair (340, 52) -> 1041
# pair (301, 110) -> 1042
# pair (378, 258) -> 1043
# pair (32, 287) -> 1044
# pair (300, 597) -> 1045
# pair (256, 117) -> 1046
# pair (32, 271) -> 1047
# pair (310, 101) -> 1048
# pair (310, 111) -> 1049
# pair (315, 302) -> 1050
# pair (399, 118) -> 1051
# pair (624, 568) -> 1052
# pair (366, 116) -> 1053
# pair (315, 108) -> 1054
# pair (114, 271) -> 1055
# pair (446, 376) -> 1056
# pair (401, 129) -> 1057
# pair (297, 263) -> 1058
# pair (431, 462) -> 1059
# pair (258, 118) -> 1060
# pair (267, 99) -> 1061
# pair (337, 453) -> 1062
# pair (109, 265) -> 1063
# pair (372, 455) -> 1064
# pair (403, 271) -> 1065
# pair (294, 49) -> 1066
# pair (824, 791) -> 1067
# pair (263, 261) -> 1068
# pair (596, 397) -> 1069
# pair (449, 820) -> 1070
# pair (104, 267) -> 1071
# pair (357, 101) -> 1072
# pair (359, 111) -> 1073
# pair (662, 118) -> 1074
# pair (532, 534) -> 1075
# pair (117, 593) -> 1076
# pair (372, 50) -> 1077
# pair (369, 110) -> 1078
# pair (361, 97) -> 1079
# pair (256, 475) -> 1080
# pair (307, 291) -> 1081
# pair (264, 471) -> 1082
# pair (269, 111) -> 1083
# pair (260, 102) -> 1084
# pair (32, 342) -> 1085
# pair (333, 318) -> 1086
# pair (334, 97) -> 1087
# pair (322, 114) -> 1088
# pair (607, 772) -> 1089
# pair (983, 568) -> 1090
# pair (331, 477) -> 1091
# pair (431, 305) -> 1092
# pair (108, 320) -> 1093
# pair (317, 109) -> 1094
# pair (32, 92) -> 1095
# pair (337, 114) -> 1096
# pair (325, 389) -> 1097
# pair (449, 356) -> 1098
# pair (370, 440) -> 1099
# pair (287, 533) -> 1100
# pair (98, 310) -> 1101
# pair (97, 275) -> 1102
# pair (256, 407) -> 1103
# pair (399, 99) -> 1104
# pair (262, 620) -> 1105
# pair (783, 548) -> 1106
# pair (326, 289) -> 1107
# pair (112, 275) -> 1108
# pair (449, 673) -> 1109
# pair (292, 987) -> 1110
# pair (105, 276) -> 1111
# pair (315, 103) -> 1112
# pair (114, 278) -> 1113
# pair (273, 400) -> 1114
# pair (466, 271) -> 1115
# pair (320, 282) -> 1116
# pair (315, 887) -> 1117
# pair (411, 680) -> 1118
# pair (262, 101) -> 1119
# pair (771, 828) -> 1120
# pair (344, 308) -> 1121
# pair (49, 52) -> 1122
# pair (264, 882) -> 1123
# pair (763, 110) -> 1124
# pair (301, 115) -> 1125
# pair (108, 296) -> 1126
# pair (108, 261) -> 1127
# pair (32, 89) -> 1128
# pair (323, 120) -> 1129
# pair (441, 114) -> 1130
# pair (1024, 487) -> 1131
# pair (269, 676) -> 1132
# pair (302, 110) -> 1133
# pair (257, 286) -> 1134
# pair (423, 376) -> 1135
# pair (264, 381) -> 1136
# pair (260, 956) -> 1137
# pair (257, 100) -> 1138
# pair (283, 437) -> 1139
# pair (117, 99) -> 1140
# pair (494, 939) -> 1141
# pair (420, 109) -> 1142
# pair (391, 312) -> 1143
# pair (270, 109) -> 1144
# pair (270, 271) -> 1145
# pair (288, 522) -> 1146
# pair (322, 652) -> 1147
# pair (401, 137) -> 1148
# pair (302, 117) -> 1149
# pair (273, 117) -> 1150
# pair (105, 436) -> 1151
# pair (32, 921) -> 1152
# pair (288, 101) -> 1153
# pair (99, 261) -> 1154
# pair (380, 977) -> 1155
# pair (633, 268) -> 1156
# pair (358, 265) -> 1157
# pair (424, 267) -> 1158
# pair (269, 386) -> 1159
# pair (258, 365) -> 1160
# pair (450, 112) -> 1161
# pair (100, 278) -> 1162
# pair (286, 267) -> 1163
# pair (687, 270) -> 1164
# pair (291, 453) -> 1165
# pair (108, 338) -> 1166
# pair (194, 178) -> 1167
# pair (270, 421) -> 1168
# pair (97, 263) -> 1169
# pair (328, 292) -> 1170
# pair (377, 339) -> 1171
# pair (331, 709) -> 1172
# pair (281, 311) -> 1173
# pair (494, 965) -> 1174
# pair (97, 290) -> 1175
# pair (341, 289) -> 1176
# pair (111, 365) -> 1177
# pair (429, 261) -> 1178
# pair (49, 50) -> 1179
# pair (444, 284) -> 1180
# pair (49, 53) -> 1181
# pair (297, 374) -> 1182
# pair (705, 277) -> 1183
# pair (483, 538) -> 1184
# pair (305, 597) -> 1185
# pair (301, 831) -> 1186
# pair (408, 261) -> 1187
# pair (413, 112) -> 1188
# pair (337, 110) -> 1189
# pair (538, 261) -> 1190
# pair (269, 318) -> 1191
# pair (267, 111) -> 1192
# pair (360, 101) -> 1193
# pair (331, 670) -> 1194
# pair (409, 268) -> 1195
# pair (644, 452) -> 1196
# pair (49, 51) -> 1197
# pair (264, 114) -> 1198
# pair (49, 55) -> 1199
# pair (413, 479) -> 1200
# pair (111, 112) -> 1201
# pair (328, 495) -> 1202
# pair (304, 281) -> 1203
# pair (337, 103) -> 1204
# pair (288, 801) -> 1205
# pair (300, 116) -> 1206
# pair (827, 473) -> 1207
# pair (326, 261) -> 1208
# pair (270, 403) -> 1209
# pair (327, 53) -> 1210
# pair (1012, 1039) -> 1211
# pair (103, 648) -> 1212
# pair (290, 265) -> 1213
# pair (258, 114) -> 1214
# pair (46, 46) -> 1215
# pair (105, 263) -> 1216
# pair (309, 326) -> 1217
# pair (327, 52) -> 1218
# pair (341, 111) -> 1219
# pair (1088, 600) -> 1220
# pair (566, 398) -> 1221
# pair (259, 103) -> 1222
# pair (852, 654) -> 1223
# pair (480, 276) -> 1224
# pair (333, 271) -> 1225
# pair (284, 117) -> 1226
# pair (313, 267) -> 1227
# pair (49, 54) -> 1228
# pair (489, 115) -> 1229
# pair (380, 110) -> 1230
# pair (649, 115) -> 1231
# pair (397, 111) -> 1232
# pair (262, 268) -> 1233
# pair (412, 352) -> 1234
# pair (105, 342) -> 1235
# pair (1080, 267) -> 1236
# pair (278, 104) -> 1237
# pair (108, 268) -> 1238
# pair (328, 339) -> 1239
# pair (579, 392) -> 1240
# pair (635, 629) -> 1241
# pair (519, 564) -> 1242
# pair (359, 275) -> 1243
# pair (514, 261) -> 1244
# pair (269, 435) -> 1245
# pair (635, 693) -> 1246
# pair (105, 381) -> 1247
# pair (282, 261) -> 1248
# pair (257, 702) -> 1249
# pair (104, 116) -> 1250
# pair (118, 435) -> 1251
# pair (486, 459) -> 1252
# pair (99, 289) -> 1253
# pair (361, 258) -> 1254
# pair (278, 101) -> 1255
# pair (100, 701) -> 1256
# pair (257, 463) -> 1257
# pair (415, 281) -> 1258
# pair (544, 57) -> 1259
# pair (102, 111) -> 1260
# pair (526, 300) -> 1261
# pair (256, 556) -> 1262
# pair (71, 69) -> 1263
# pair (1046, 268) -> 1264
# pair (118, 325) -> 1265
# pair (615, 1011) -> 1266
# pair (359, 97) -> 1267
# pair (262, 861) -> 1268
# pair (307, 940) -> 1269
# pair (483, 116) -> 1270
# pair (735, 115) -> 1271
# pair (100, 265) -> 1272
# pair (115, 276) -> 1273
# pair (957, 101) -> 1274
# pair (395, 284) -> 1275
# pair (273, 115) -> 1276
# pair (549, 261) -> 1277
# pair (284, 112) -> 1278
# pair (462, 258) -> 1279
# pair (647, 290) -> 1280
# pair (415, 404) -> 1281
# pair (358, 97) -> 1282
# pair (102, 97) -> 1283
# pair (300, 753) -> 1284
# pair (310, 400) -> 1285
# pair (256, 693) -> 1286
# pair (118, 381) -> 1287
# pair (320, 354) -> 1288
# pair (1139, 740) -> 1289
# pair (105, 265) -> 1290
# pair (108, 397) -> 1291
# pair (32, 316) -> 1292
# pair (359, 267) -> 1293
# pair (297, 109) -> 1294
# pair (343, 800) -> 1295
# pair (279, 112) -> 1296
# pair (286, 776) -> 1297
# pair (569, 112) -> 1298
# pair (1186, 416) -> 1299
# pair (359, 727) -> 1300
# pair (349, 114) -> 1301
# pair (411, 879) -> 1302
# pair (271, 97) -> 1303
# pair (267, 103) -> 1304
# pair (483, 1036) -> 1305
# pair (261, 97) -> 1306
# pair (32, 35) -> 1307
# pair (288, 284) -> 1308
# pair (264, 117) -> 1309
# pair (391, 263) -> 1310
# pair (532, 352) -> 1311
# pair (683, 485) -> 1312
# pair (975, 421) -> 1313
# pair (264, 104) -> 1314
# pair (790, 293) -> 1315
# pair (270, 110) -> 1316
# pair (1008, 268) -> 1317
# pair (1132, 277) -> 1318
# pair (99, 117) -> 1319
# pair (264, 320) -> 1320
# pair (846, 276) -> 1321
# pair (66, 1263) -> 1322
# pair (586, 373) -> 1323
# pair (594, 618) -> 1324
# pair (105, 418) -> 1325
# pair (49, 49) -> 1326
# pair (456, 108) -> 1327
# pair (383, 112) -> 1328
# pair (505, 56) -> 1329
# pair (884, 1166) -> 1330
# pair (1187, 291) -> 1331
# pair (535, 885) -> 1332
# pair (295, 318) -> 1333
# pair (315, 122) -> 1334
# pair (334, 407) -> 1335
# pair (333, 481) -> 1336
# pair (681, 457) -> 1337
# pair (256, 105) -> 1338
# pair (500, 1060) -> 1339
# pair (285, 108) -> 1340
# pair (929, 1074) -> 1341
# pair (293, 101) -> 1342
# pair (631, 352) -> 1343
# pair (455, 48) -> 1344
# pair (518, 102) -> 1345
# pair (259, 565) -> 1346
# pair (431, 326) -> 1347
# pair (114, 350) -> 1348
# pair (265, 281) -> 1349
# pair (384, 682) -> 1350
# pair (106, 111) -> 1351
# pair (122, 101) -> 1352
# pair (50, 52) -> 1353
# pair (295, 266) -> 1354
# pair (343, 345) -> 1355
# pair (334, 273) -> 1356
# pair (102, 350) -> 1357
# pair (280, 290) -> 1358
# pair (332, 115) -> 1359
# pair (413, 970) -> 1360
# pair (323, 374) -> 1361
# pair (369, 543) -> 1362
# pair (347, 373) -> 1363
# pair (300, 459) -> 1364
# pair (848, 364) -> 1365
# pair (348, 110) -> 1366
# pair (98, 316) -> 1367
# pair (516, 49) -> 1368
# pair (819, 285) -> 1369
# pair (264, 394) -> 1370
# pair (257, 396) -> 1371
# pair (318, 1019) -> 1372
# pair (443, 562) -> 1373
# pair (517, 786) -> 1374
# pair (443, 101) -> 1375
# pair (386, 270) -> 1376
# pair (370, 877) -> 1377
# pair (54, 52) -> 1378
# pair (399, 102) -> 1379
# pair (297, 110) -> 1380
# pair (1261, 1177) -> 1381
# pair (283, 625) -> 1382
# pair (330, 99) -> 1383
# pair (327, 57) -> 1384
# pair (378, 111) -> 1385
# pair (114, 98) -> 1386
# pair (266, 365) -> 1387
# pair (369, 1322) -> 1388
# pair (105, 442) -> 1389
# pair (262, 355) -> 1390
# pair (362, 979) -> 1391
# pair (104, 388) -> 1392
# pair (1328, 942) -> 1393
# pair (295, 381) -> 1394
# pair (1339, 833) -> 1395
# pair (284, 118) -> 1396
# pair (262, 265) -> 1397
# pair (317, 292) -> 1398
# pair (1098, 381) -> 1399
# pair (101, 281) -> 1400
# pair (261, 111) -> 1401
# pair (1043, 468) -> 1402
# pair (288, 293) -> 1403
# pair (520, 701) -> 1404
# pair (102, 335) -> 1405
# pair (462, 111) -> 1406
# pair (653, 112) -> 1407
# pair (262, 258) -> 1408
# pair (759, 342) -> 1409
# pair (527, 49) -> 1410
# pair (310, 108) -> 1411
# pair (1279, 797) -> 1412
# pair (469, 48) -> 1413
# pair (117, 311) -> 1414
# pair (316, 108) -> 1415
# pair (514, 268) -> 1416
# pair (323, 809) -> 1417
# pair (291, 108) -> 1418
# pair (297, 99) -> 1419
# pair (323, 100) -> 1420
# pair (997, 492) -> 1421
# pair (460, 923) -> 1422
# pair (305, 108) -> 1423
# pair (259, 395) -> 1424
# pair (323, 108) -> 1425
# pair (596, 912) -> 1426
# pair (315, 268) -> 1427
# pair (97, 117) -> 1428
# pair (740, 278) -> 1429
# pair (313, 114) -> 1430
# pair (99, 641) -> 1431
# pair (826, 436) -> 1432
# pair (266, 110) -> 1433
# pair (391, 114) -> 1434
# pair (267, 118) -> 1435
# pair (369, 376) -> 1436
# pair (494, 101) -> 1437
# pair (194, 170) -> 1438
# pair (321, 117) -> 1439
# pair (327, 55) -> 1440
# pair (316, 111) -> 1441
# pair (269, 326) -> 1442
# pair (321, 320) -> 1443
# pair (32, 46) -> 1444
# pair (393, 157) -> 1445
# pair (109, 350) -> 1446
# pair (360, 990) -> 1447
# pair (265, 389) -> 1448
# pair (116, 442) -> 1449
# pair (101, 98) -> 1450
# pair (313, 356) -> 1451
# pair (369, 115) -> 1452
# pair (1099, 504) -> 1453
# pair (337, 419) -> 1454
# pair (333, 407) -> 1455
# pair (331, 774) -> 1456
# pair (432, 458) -> 1457
# pair (1289, 111) -> 1458
# pair (32, 44) -> 1459
# pair (288, 727) -> 1460
# pair (460, 305) -> 1461
# pair (309, 325) -> 1462
# pair (333, 111) -> 1463
# pair (640, 785) -> 1464
# pair (320, 485) -> 1465
# pair (281, 390) -> 1466
# pair (278, 293) -> 1467
# pair (262, 1076) -> 1468
# pair (307, 273) -> 1469
# pair (361, 111) -> 1470
# pair (275, 109) -> 1471
# pair (99, 268) -> 1472
# pair (297, 116) -> 1473
# pair (325, 485) -> 1474
# pair (102, 101) -> 1475
# pair (287, 101) -> 1476
# pair (410, 400) -> 1477
# pair (440, 122) -> 1478
# pair (322, 443) -> 1479
# pair (569, 326) -> 1480
# pair (428, 156) -> 1481
# pair (811, 265) -> 1482
# pair (315, 261) -> 1483
# pair (99, 107) -> 1484
# pair (357, 111) -> 1485
# pair (412, 466) -> 1486
# pair (378, 101) -> 1487
# pair (313, 101) -> 1488
# pair (359, 316) -> 1489
# pair (1233, 496) -> 1490
# pair (334, 1116) -> 1491
# pair (349, 108) -> 1492
# pair (333, 293) -> 1493
# pair (1383, 479) -> 1494
# pair (790, 709) -> 1495
# pair (549, 374) -> 1496
# pair (119, 119) -> 1497
# pair (338, 109) -> 1498
# pair (834, 1164) -> 1499
# pair (317, 116) -> 1500
# pair (115, 332) -> 1501
# pair (53, 48) -> 1502
# pair (450, 292) -> 1503
# pair (32, 440) -> 1504
# pair (342, 101) -> 1505
# pair (465, 109) -> 1506
# pair (325, 104) -> 1507
# pair (267, 373) -> 1508
# pair (446, 366) -> 1509
# pair (1006, 488) -> 1510
# pair (561, 108) -> 1511
# pair (1200, 924) -> 1512
# pair (105, 720) -> 1513
# pair (355, 114) -> 1514
# pair (353, 97) -> 1515
# pair (340, 50) -> 1516
# pair (274, 261) -> 1517
# pair (314, 670) -> 1518
# pair (627, 1297) -> 1519
# pair (269, 918) -> 1520
# pair (307, 326) -> 1521
# pair (305, 599) -> 1522
# pair (102, 278) -> 1523
# pair (450, 281) -> 1524
# pair (313, 520) -> 1525
# pair (1184, 443) -> 1526
# pair (632, 111) -> 1527
# pair (456, 100) -> 1528
# pair (325, 111) -> 1529
# pair (105, 533) -> 1530
# pair (32, 114) -> 1531
# pair (360, 261) -> 1532
# pair (288, 278) -> 1533
# pair (411, 722) -> 1534
# pair (102, 781) -> 1535
# pair (318, 97) -> 1536
# pair (117, 100) -> 1537
# pair (331, 1291) -> 1538
# pair (262, 490) -> 1539
# pair (322, 502) -> 1540
# pair (271, 447) -> 1541
# pair (327, 56) -> 1542
# pair (607, 115) -> 1543
# pair (1360, 555) -> 1544
# pair (369, 1223) -> 1545
# pair (263, 275) -> 1546
# pair (333, 788) -> 1547
# pair (1119, 286) -> 1548
# pair (259, 966) -> 1549
# pair (290, 539) -> 1550
# pair (116, 439) -> 1551
# pair (315, 109) -> 1552
# pair (325, 736) -> 1553
# pair (97, 436) -> 1554
# pair (644, 351) -> 1555
# pair (116, 273) -> 1556
# pair (408, 971) -> 1557
# pair (343, 289) -> 1558
# pair (335, 392) -> 1559
# pair (105, 373) -> 1560
# pair (477, 117) -> 1561
# pair (361, 101) -> 1562
# pair (118, 287) -> 1563
# pair (283, 101) -> 1564
# pair (55, 56) -> 1565
# pair (431, 971) -> 1566
# pair (817, 276) -> 1567
# pair (115, 261) -> 1568
# pair (99, 275) -> 1569
# pair (770, 620) -> 1570
# pair (264, 974) -> 1571
# pair (861, 350) -> 1572
# pair (297, 290) -> 1573
# pair (259, 487) -> 1574
# pair (105, 107) -> 1575
# pair (548, 804) -> 1576
# pair (611, 373) -> 1577
# pair (307, 332) -> 1578
# pair (631, 105) -> 1579
# pair (552, 556) -> 1580
# pair (589, 1387) -> 1581
# pair (341, 258) -> 1582
# pair (1262, 394) -> 1583
# pair (432, 345) -> 1584
# pair (576, 112) -> 1585
# pair (100, 470) -> 1586
# pair (725, 258) -> 1587
# pair (896, 302) -> 1588
# pair (297, 493) -> 1589
# pair (327, 51) -> 1590
# pair (108, 350) -> 1591
# pair (792, 1221) -> 1592
# pair (384, 99) -> 1593
# pair (327, 50) -> 1594
# pair (506, 122) -> 1595
# pair (288, 457) -> 1596
# pair (1101, 382) -> 1597
# pair (295, 108) -> 1598
# pair (306, 410) -> 1599
# pair (262, 396) -> 1600
# pair (1037, 282) -> 1601
# pair (526, 109) -> 1602
# pair (793, 694) -> 1603
# pair (309, 293) -> 1604
# pair (519, 585) -> 1605
# pair (647, 1110) -> 1606
# pair (1034, 926) -> 1607
# pair (339, 731) -> 1608
# pair (99, 267) -> 1609
# pair (659, 758) -> 1610
# pair (527, 48) -> 1611
# pair (399, 112) -> 1612
# pair (382, 636) -> 1613
# pair (112, 289) -> 1614
# pair (109, 491) -> 1615
# pair (105, 285) -> 1616
# pair (362, 278) -> 1617
# pair (309, 316) -> 1618
# pair (378, 97) -> 1619
# pair (313, 318) -> 1620
# pair (32, 58) -> 1621
# pair (506, 99) -> 1622
# pair (112, 330) -> 1623
# pair (326, 268) -> 1624
# pair (295, 293) -> 1625
# pair (120, 457) -> 1626
# pair (1047, 433) -> 1627
# pair (272, 114) -> 1628
# pair (384, 114) -> 1629
# pair (334, 444) -> 1630
# pair (454, 272) -> 1631
# pair (494, 655) -> 1632
# pair (584, 828) -> 1633
# pair (259, 286) -> 1634
# pair (391, 585) -> 1635
# pair (778, 122) -> 1636
# pair (1124, 355) -> 1637
# pair (307, 530) -> 1638
# pair (427, 111) -> 1639
# pair (262, 1093) -> 1640
# pair (986, 548) -> 1641
# pair (327, 54) -> 1642
# pair (266, 114) -> 1643
# pair (333, 101) -> 1644
# pair (259, 109) -> 1645
# pair (300, 365) -> 1646
# pair (1089, 105) -> 1647
# pair (292, 110) -> 1648
# pair (638, 797) -> 1649
# pair (771, 1373) -> 1650
# pair (264, 1494) -> 1651
# pair (32, 122) -> 1652
# pair (884, 110) -> 1653
# pair (194, 176) -> 1654
# pair (313, 293) -> 1655
# pair (320, 103) -> 1656
# pair (281, 312) -> 1657
# pair (613, 100) -> 1658
# pair (260, 1251) -> 1659
# pair (626, 270) -> 1660
# pair (591, 1213) -> 1661
# pair (544, 56) -> 1662
# pair (553, 286) -> 1663
# pair (454, 276) -> 1664
# pair (264, 356) -> 1665
# pair (300, 414) -> 1666
# pair (510, 376) -> 1667
# pair (420, 271) -> 1668
# pair (110, 485) -> 1669
# pair (913, 948) -> 1670
# pair (334, 335) -> 1671
# pair (116, 305) -> 1672
# pair (1014, 464) -> 1673
# pair (105, 547) -> 1674
# pair (1073, 105) -> 1675
# pair (523, 97) -> 1676
# pair (98, 583) -> 1677
# pair (275, 536) -> 1678
# pair (716, 265) -> 1679
# pair (51, 48) -> 1680
# pair (261, 281) -> 1681
# pair (480, 776) -> 1682
# pair (369, 73) -> 1683
# pair (116, 275) -> 1684
# pair (105, 499) -> 1685
# pair (413, 676) -> 1686
# pair (632, 97) -> 1687
# pair (32, 453) -> 1688
# pair (277, 108) -> 1689
# pair (532, 864) -> 1690
# pair (307, 366) -> 1691
# pair (368, 872) -> 1692
# pair (519, 365) -> 1693
# pair (258, 99) -> 1694
# pair (362, 103) -> 1695
# pair (617, 1035) -> 1696
# pair (349, 565) -> 1697
# pair (283, 1613) -> 1698
# pair (339, 392) -> 1699
# pair (899, 339) -> 1700
# pair (103, 268) -> 1701
# pair (290, 270) -> 1702
# pair (115, 270) -> 1703
# pair (687, 97) -> 1704
# pair (99, 108) -> 1705
# pair (273, 261) -> 1706
# pair (117, 97) -> 1707
# pair (1091, 98) -> 1708
# pair (112, 104) -> 1709
# pair (807, 699) -> 1710
# pair (337, 100) -> 1711
# pair (347, 722) -> 1712
# pair (57, 48) -> 1713
# pair (297, 98) -> 1714
# pair (105, 1404) -> 1715
# pair (111, 100) -> 1716
# pair (54, 48) -> 1717
# pair (317, 654) -> 1718
# pair (334, 796) -> 1719
# pair (112, 318) -> 1720
# pair (320, 99) -> 1721
# pair (264, 502) -> 1722
# pair (739, 277) -> 1723
# pair (320, 261) -> 1724
# pair (359, 101) -> 1725
# pair (265, 289) -> 1726
# pair (685, 559) -> 1727
# pair (755, 97) -> 1728
# pair (611, 1597) -> 1729
# pair (427, 97) -> 1730
# pair (288, 410) -> 1731
# pair (341, 101) -> 1732
# pair (341, 267) -> 1733
# pair (288, 438) -> 1734
# pair (103, 110) -> 1735
# pair (456, 296) -> 1736
# pair (345, 98) -> 1737
# pair (346, 296) -> 1738
# pair (114, 121) -> 1739
# pair (334, 706) -> 1740
# pair (423, 112) -> 1741
# pair (704, 1392) -> 1742
# pair (102, 275) -> 1743
# pair (532, 100) -> 1744
# pair (403, 872) -> 1745
# pair (360, 625) -> 1746
# pair (343, 111) -> 1747
# pair (303, 1180) -> 1748
# pair (317, 404) -> 1749
# pair (465, 277) -> 1750
# pair (259, 447) -> 1751
# pair (1067, 258) -> 1752
# pair (447, 109) -> 1753
# pair (1082, 103) -> 1754
# pair (408, 117) -> 1755
# pair (449, 111) -> 1756
# pair (369, 364) -> 1757
# pair (333, 490) -> 1758
# pair (561, 751) -> 1759
# pair (101, 352) -> 1760
# pair (297, 100) -> 1761
# pair (638, 277) -> 1762
# pair (116, 115) -> 1763
# pair (333, 1156) -> 1764
# pair (269, 337) -> 1765
# pair (264, 293) -> 1766
# pair (331, 112) -> 1767
# pair (120, 111) -> 1768
# pair (260, 364) -> 1769
# pair (333, 97) -> 1770
# pair (118, 268) -> 1771
# pair (334, 537) -> 1772
# pair (99, 315) -> 1773
# pair (286, 265) -> 1774
# pair (321, 438) -> 1775
# pair (331, 702) -> 1776
# pair (269, 1274) -> 1777
# pair (331, 105) -> 1778
# pair (358, 111) -> 1779
# pair (264, 273) -> 1780
# pair (353, 382) -> 1781
# pair (848, 671) -> 1782
# pair (708, 285) -> 1783
# pair (108, 278) -> 1784
# pair (105, 392) -> 1785
# pair (778, 311) -> 1786
# pair (50, 50) -> 1787
# pair (296, 108) -> 1788
# pair (117, 98) -> 1789
# pair (32, 47) -> 1790
# pair (865, 115) -> 1791
# pair (359, 266) -> 1792
# pair (116, 116) -> 1793
# pair (335, 281) -> 1794
# pair (56, 48) -> 1795
# pair (343, 268) -> 1796
# pair (295, 320) -> 1797
# pair (321, 366) -> 1798
# pair (420, 311) -> 1799
# pair (523, 1150) -> 1800
# pair (713, 290) -> 1801
# pair (112, 103) -> 1802
# pair (332, 103) -> 1803
# pair (456, 493) -> 1804
# pair (55, 48) -> 1805
# pair (637, 99) -> 1806
# pair (579, 284) -> 1807
# pair (323, 1546) -> 1808
# pair (427, 923) -> 1809
# pair (663, 492) -> 1810
# pair (308, 61) -> 1811
# pair (99, 488) -> 1812
# pair (1520, 919) -> 1813
# pair (107, 97) -> 1814
# pair (1347, 400) -> 1815
# pair (1105, 355) -> 1816
# pair (799, 302) -> 1817
# pair (786, 787) -> 1818
# pair (853, 118) -> 1819
# pair (1374, 1062) -> 1820
# pair (529, 599) -> 1821
# pair (288, 267) -> 1822
# pair (461, 114) -> 1823
# pair (958, 398) -> 1824
# pair (315, 285) -> 1825
# pair (260, 114) -> 1826
# pair (32, 59) -> 1827
# pair (116, 452) -> 1828
# pair (399, 758) -> 1829
# pair (1029, 400) -> 1830
# pair (104, 110) -> 1831
# pair (273, 808) -> 1832
# pair (1084, 273) -> 1833
# pair (881, 435) -> 1834
# pair (257, 116) -> 1835
# pair (409, 121) -> 1836
# pair (280, 312) -> 1837
# pair (259, 514) -> 1838
# pair (395, 97) -> 1839
# pair (301, 433) -> 1840
# pair (660, 717) -> 1841
# pair (440, 507) -> 1842
# pair (307, 625) -> 1843
# pair (906, 599) -> 1844
# pair (1341, 641) -> 1845
# pair (266, 101) -> 1846
# pair (321, 273) -> 1847
# pair (263, 284) -> 1848
# pair (322, 1206) -> 1849
# pair (516, 53) -> 1850
# pair (456, 110) -> 1851
# pair (424, 995) -> 1852
# pair (712, 390) -> 1853
# pair (52, 48) -> 1854
# pair (1511, 1677) -> 1855
# pair (767, 296) -> 1856
# pair (403, 352) -> 1857
# pair (327, 49) -> 1858
# pair (116, 435) -> 1859
# pair (553, 116) -> 1860
# pair (112, 382) -> 1861
# pair (342, 600) -> 1862
# pair (922, 515) -> 1863
# pair (1398, 1275) -> 1864
# pair (370, 325) -> 1865
# pair (117, 365) -> 1866
# pair (116, 470) -> 1867
# pair (359, 1312) -> 1868
# pair (32, 38) -> 1869
# pair (1585, 1572) -> 1870
# pair (115, 268) -> 1871
# pair (283, 583) -> 1872
# pair (988, 926) -> 1873
# pair (400, 258) -> 1874
# pair (1246, 406) -> 1875
# pair (258, 271) -> 1876
# pair (748, 440) -> 1877
# pair (307, 261) -> 1878
# pair (749, 350) -> 1879
# pair (729, 1100) -> 1880
# pair (300, 103) -> 1881
# pair (856, 265) -> 1882
# pair (460, 732) -> 1883
# pair (484, 897) -> 1884
# pair (98, 114) -> 1885
# pair (473, 112) -> 1886
# pair (523, 284) -> 1887
# pair (431, 1477) -> 1888
# pair (359, 117) -> 1889
# pair (286, 270) -> 1890
# pair (527, 51) -> 1891
# pair (272, 265) -> 1892
# pair (396, 290) -> 1893
# pair (1269, 350) -> 1894
# pair (1069, 345) -> 1895
# pair (527, 50) -> 1896
# pair (1085, 694) -> 1897
# pair (303, 562) -> 1898
# pair (322, 315) -> 1899
# pair (32, 62) -> 1900
# pair (757, 315) -> 1901
# pair (259, 1588) -> 1902
# pair (333, 325) -> 1903
# pair (449, 1102) -> 1904
# pair (901, 277) -> 1905
# pair (623, 1054) -> 1906
# pair (357, 1432) -> 1907
# pair (102, 430) -> 1908
# pair (41, 59) -> 1909
# pair (516, 52) -> 1910
# pair (532, 1195) -> 1911
# pair (665, 571) -> 1912
# pair (277, 258) -> 1913
# pair (894, 1040) -> 1914
# pair (787, 270) -> 1915
# pair (32, 119) -> 1916
# pair (260, 421) -> 1917
# pair (348, 296) -> 1918
# pair (273, 104) -> 1919
# pair (417, 1608) -> 1920
# pair (905, 302) -> 1921
# pair (333, 270) -> 1922
# pair (306, 117) -> 1923
# pair (689, 270) -> 1924
# pair (516, 55) -> 1925
# pair (1135, 101) -> 1926
# pair (360, 276) -> 1927
# pair (296, 1065) -> 1928
# pair (1194, 381) -> 1929
# pair (1525, 284) -> 1930
# pair (1468, 278) -> 1931
# pair (274, 265) -> 1932
# pair (1769, 406) -> 1933
# pair (340, 48) -> 1934
# pair (1136, 284) -> 1935
# pair (1051, 1364) -> 1936
# pair (466, 117) -> 1937
# pair (382, 117) -> 1938
# pair (284, 110) -> 1939
# pair (260, 109) -> 1940
# pair (919, 311) -> 1941
# pair (1086, 281) -> 1942
# pair (519, 734) -> 1943
# pair (313, 275) -> 1944
# pair (541, 112) -> 1945
# pair (118, 271) -> 1946
# pair (1146, 1284) -> 1947
# pair (318, 1204) -> 1948
# pair (300, 108) -> 1949
# pair (50, 53) -> 1950
# pair (516, 56) -> 1951
# pair (454, 275) -> 1952
# pair (291, 599) -> 1953
# pair (516, 57) -> 1954
# pair (677, 990) -> 1955
# pair (57, 57) -> 1956
# pair (412, 374) -> 1957
# pair (275, 268) -> 1958
# pair (283, 266) -> 1959
# pair (1032, 673) -> 1960
# pair (281, 110) -> 1961
# pair (535, 337) -> 1962
# pair (756, 86) -> 1963
# pair (109, 394) -> 1964
# pair (117, 395) -> 1965
# pair (350, 390) -> 1966
# pair (97, 107) -> 1967
# pair (281, 363) -> 1968
# pair (411, 271) -> 1969
# pair (322, 1013) -> 1970
# pair (360, 530) -> 1971
# pair (283, 706) -> 1972
# pair (108, 498) -> 1973
# pair (50, 51) -> 1974
# pair (1104, 639) -> 1975
# pair (357, 335) -> 1976
# pair (1266, 312) -> 1977
# pair (357, 271) -> 1978
# pair (334, 397) -> 1979
# pair (54, 53) -> 1980
# pair (111, 258) -> 1981
# pair (449, 284) -> 1982
# pair (1053, 419) -> 1983
# pair (121, 115) -> 1984
# pair (362, 404) -> 1985
# pair (415, 447) -> 1986
# pair (888, 582) -> 1987
# pair (364, 97) -> 1988
# pair (259, 339) -> 1989
# pair (906, 802) -> 1990
# pair (46, 44) -> 1991
# pair (269, 293) -> 1992
# pair (725, 97) -> 1993
# pair (109, 355) -> 1994
# pair (655, 404) -> 1995
# pair (767, 270) -> 1996
# pair (102, 332) -> 1997
# pair (630, 354) -> 1998
# pair (424, 293) -> 1999
# pair (288, 592) -> 2000
# pair (102, 116) -> 2001
# pair (50, 49) -> 2002
# pair (1327, 1038) -> 2003
# pair (834, 286) -> 2004
# pair (391, 277) -> 2005
# pair (334, 351) -> 2006
# pair (819, 758) -> 2007
# pair (516, 54) -> 2008
# pair (307, 266) -> 2009
# pair (321, 310) -> 2010
# pair (289, 365) -> 2011
# pair (870, 1163) -> 2012
# pair (260, 632) -> 2013
# pair (103, 356) -> 2014
# pair (460, 938) -> 2015
# pair (292, 109) -> 2016
# pair (1437, 342) -> 2017
# pair (1120, 390) -> 2018
# pair (120, 97) -> 2019
# pair (526, 630) -> 2020
# pair (300, 1115) -> 2021
# pair (368, 507) -> 2022
# pair (699, 688) -> 2023
# pair (724, 669) -> 2024
# pair (262, 520) -> 2025
# pair (486, 263) -> 2026
# pair (381, 293) -> 2027
# pair (556, 110) -> 2028
# pair (1308, 312) -> 2029
# pair (99, 439) -> 2030
# pair (313, 258) -> 2031
# pair (594, 363) -> 2032
# pair (118, 316) -> 2033
# pair (333, 857) -> 2034
# pair (577, 458) -> 2035
# pair (1346, 266) -> 2036
# pair (259, 1429) -> 2037
# pair (118, 296) -> 2038
# pair (331, 293) -> 2039
# pair (104, 289) -> 2040
# pair (264, 326) -> 2041
# pair (256, 511) -> 2042
# pair (54, 56) -> 2043
# pair (506, 311) -> 2044
# pair (622, 1065) -> 2045
# pair (264, 354) -> 2046
# pair (659, 115) -> 2047
# pair (118, 497) -> 2048
# pair (631, 559) -> 2049
# pair (322, 275) -> 2050
# pair (331, 545) -> 2051
# pair (469, 49) -> 2052
# pair (102, 102) -> 2053
# pair (106, 1802) -> 2054
# pair (83, 66) -> 2055
# pair (305, 103) -> 2056
# pair (98, 275) -> 2057
# pair (259, 515) -> 2058
# pair (678, 590) -> 2059
# pair (292, 108) -> 2060
# pair (322, 284) -> 2061
# pair (1123, 351) -> 2062
# pair (316, 101) -> 2063
# pair (115, 265) -> 2064
# pair (398, 547) -> 2065
# pair (1433, 293) -> 2066
# pair (1823, 404) -> 2067
# pair (260, 479) -> 2068
# pair (1417, 587) -> 2069
# pair (55, 53) -> 2070
# pair (594, 263) -> 2071
# pair (510, 418) -> 2072
# pair (708, 400) -> 2073
# pair (893, 311) -> 2074
# pair (1300, 1541) -> 2075
# pair (259, 543) -> 2076
# pair (107, 101) -> 2077
# pair (429, 268) -> 2078
# pair (456, 395) -> 2079
# pair (519, 414) -> 2080
# pair (823, 504) -> 2081
# pair (259, 281) -> 2082
# pair (412, 110) -> 2083
# pair (370, 318) -> 2084
# pair (281, 445) -> 2085
# pair (334, 457) -> 2086
# pair (321, 291) -> 2087
# pair (541, 275) -> 2088
# pair (112, 115) -> 2089
# pair (484, 270) -> 2090
# pair (391, 109) -> 2091
# pair (339, 275) -> 2092
# pair (47, 47) -> 2093
# pair (1182, 1998) -> 2094
# pair (117, 285) -> 2095
# pair (1978, 1993) -> 2096
# pair (839, 1127) -> 2097
# pair (518, 286) -> 2098
# pair (309, 112) -> 2099
# pair (325, 433) -> 2100
# pair (716, 335) -> 2101
# pair (51, 51) -> 2102
# pair (122, 111) -> 2103
# pair (573, 390) -> 2104
# pair (516, 50) -> 2105
# pair (397, 261) -> 2106
# pair (58, 2093) -> 2107
# pair (1153, 1810) -> 2108
# pair (116, 394) -> 2109
# pair (267, 278) -> 2110
# pair (263, 268) -> 2111
# pair (358, 843) -> 2112
# pair (265, 265) -> 2113
# pair (343, 1818) -> 2114
# pair (407, 111) -> 2115
# pair (1193, 119) -> 2116
# pair (45, 45) -> 2117
# pair (1106, 794) -> 2118
# pair (677, 289) -> 2119
# pair (103, 267) -> 2120
# pair (56, 53) -> 2121
# pair (309, 267) -> 2122
# pair (1521, 1071) -> 2123
# pair (505, 55) -> 2124
# pair (52, 53) -> 2125
# pair (273, 351) -> 2126
# pair (259, 473) -> 2127
# pair (1020, 476) -> 2128
# pair (516, 51) -> 2129
# pair (613, 680) -> 2130
# pair (376, 275) -> 2131
# pair (1462, 1874) -> 2132
# pair (1159, 488) -> 2133
# pair (438, 101) -> 2134
# pair (321, 101) -> 2135
# pair (54, 55) -> 2136
# pair (104, 105) -> 2137
# pair (850, 56) -> 2138
# pair (1189, 296) -> 2139
# pair (99, 326) -> 2140
# pair (273, 100) -> 2141
# pair (756, 73) -> 2142
# pair (353, 498) -> 2143
# pair (313, 105) -> 2144
# pair (755, 111) -> 2145
# pair (301, 1386) -> 2146
# pair (529, 992) -> 2147
# pair (601, 1389) -> 2148
# pair (32, 315) -> 2149
# pair (1236, 690) -> 2150
# pair (119, 97) -> 2151
# pair (54, 57) -> 2152
# pair (99, 400) -> 2153
# pair (1141, 311) -> 2154
# pair (627, 1304) -> 2155
# pair (98, 258) -> 2156
# pair (412, 99) -> 2157
# pair (54, 51) -> 2158
# pair (105, 470) -> 2159
# pair (1917, 566) -> 2160
# pair (256, 416) -> 2161
# pair (822, 97) -> 2162
# pair (108, 121) -> 2163
# pair (518, 994) -> 2164
# pair (537, 1126) -> 2165
# pair (900, 115) -> 2166
# pair (303, 800) -> 2167
# pair (1719, 751) -> 2168
# pair (655, 302) -> 2169
# pair (370, 275) -> 2170
# pair (486, 1913) -> 2171
# pair (444, 261) -> 2172
# pair (264, 719) -> 2173
# pair (537, 316) -> 2174
# pair (314, 1587) -> 2175
# pair (653, 433) -> 2176
# pair (270, 114) -> 2177
# pair (662, 1414) -> 2178
# pair (645, 302) -> 2179
# pair (412, 120) -> 2180
# pair (1601, 355) -> 2181
# pair (468, 312) -> 2182
# pair (949, 267) -> 2183
# pair (280, 374) -> 2184
# pair (1077, 49) -> 2185
# pair (1081, 764) -> 2186
# pair (560, 109) -> 2187
# pair (768, 420) -> 2188
# pair (575, 48) -> 2189
# pair (591, 118) -> 2190
# pair (103, 296) -> 2191
# pair (399, 1762) -> 2192
# pair (350, 311) -> 2193
# pair (444, 267) -> 2194
# pair (510, 587) -> 2195
# pair (1009, 118) -> 2196
# pair (50, 56) -> 2197
# pair (291, 984) -> 2198
# pair (1044, 101) -> 2199
# pair (1434, 109) -> 2200
# pair (342, 268) -> 2201
# pair (1622, 426) -> 2202
# pair (283, 938) -> 2203
# pair (1194, 1027) -> 2204
# pair (411, 363) -> 2205
# pair (117, 310) -> 2206
# pair (121, 97) -> 2207
# pair (333, 105) -> 2208
# pair (260, 1848) -> 2209
# pair (407, 316) -> 2210
# pair (300, 97) -> 2211
# pair (517, 99) -> 2212
# pair (505, 48) -> 2213
# pair (309, 111) -> 2214
# pair (1143, 638) -> 2215
# pair (295, 354) -> 2216
# pair (305, 114) -> 2217
# pair (267, 302) -> 2218
# pair (262, 112) -> 2219
# pair (309, 355) -> 2220
# pair (52, 56) -> 2221
# pair (32, 300) -> 2222
# pair (256, 452) -> 2223
# pair (1390, 447) -> 2224
# pair (928, 386) -> 2225
# pair (295, 1478) -> 2226
# pair (99, 534) -> 2227
# pair (437, 404) -> 2228
# pair (264, 1576) -> 2229
# pair (99, 310) -> 2230
# pair (659, 258) -> 2231
# pair (305, 1115) -> 2232
# pair (101, 120) -> 2233
# pair (345, 268) -> 2234
# pair (275, 100) -> 2235
# pair (370, 101) -> 2236
# pair (692, 277) -> 2237
# pair (110, 267) -> 2238
# pair (281, 352) -> 2239
# pair (261, 115) -> 2240
# pair (118, 993) -> 2241
# pair (437, 748) -> 2242
# pair (257, 364) -> 2243
# pair (369, 108) -> 2244
# pair (361, 267) -> 2245
# pair (1014, 470) -> 2246
# pair (118, 261) -> 2247
# pair (289, 105) -> 2248
# pair (1171, 1862) -> 2249
# pair (301, 496) -> 2250
# pair (1479, 111) -> 2251
# pair (32, 37) -> 2252
# pair (1268, 430) -> 2253
# pair (1849, 568) -> 2254
# pair (409, 266) -> 2255
# pair (321, 268) -> 2256
# pair (51, 53) -> 2257
# pair (293, 108) -> 2258
# pair (526, 292) -> 2259
# pair (1776, 715) -> 2260
# pair (112, 625) -> 2261
# pair (1580, 1290) -> 2262
# pair (32, 120) -> 2263
# pair (505, 49) -> 2264
# pair (358, 117) -> 2265
# pair (111, 107) -> 2266
# pair (321, 316) -> 2267
# pair (1538, 571) -> 2268
# pair (323, 110) -> 2269
# pair (55, 55) -> 2270
# pair (288, 529) -> 2271
# pair (116, 291) -> 2272
# pair (1593, 639) -> 2273
# pair (105, 315) -> 2274
# pair (257, 809) -> 2275
# pair (290, 267) -> 2276
# pair (317, 2131) -> 2277
# pair (796, 296) -> 2278
# pair (408, 97) -> 2279
# pair (321, 930) -> 2280
# ...
# pair (97, 390) -> 4347
# pair (2649, 268) -> 4348
# pair (2349, 765) -> 4349
# pair (277, 311) -> 4350
# pair (357, 826) -> 4351
# pair (1128, 355) -> 4352
# pair (320, 890) -> 4353
# pair (1963, 2547) -> 4354
# pair (759, 2745) -> 4355
# pair (1526, 355) -> 4356
# pair (80, 111) -> 4357
# pair (408, 3145) -> 4358
# pair (1320, 311) -> 4359
# pair (273, 355) -> 4360
# pair (1948, 430) -> 4361
# pair (424, 268) -> 4362
# pair (1042, 719) -> 4363
# pair (333, 1788) -> 4364
# pair (1403, 281) -> 4365
# pair (2307, 3559) -> 4366
# pair (313, 2588) -> 4367
# pair (297, 395) -> 4368
# pair (313, 83) -> 4369
# pair (855, 1839) -> 4370
# pair (1262, 567) -> 4371
# pair (271, 433) -> 4372
# pair (839, 907) -> 4373
# pair (2212, 539) -> 4374
# pair (224, 184) -> 4375
# pair (812, 51) -> 4376
# pair (747, 1550) -> 4377
# pair (594, 2228) -> 4378
# pair (3234, 107) -> 4379
# pair (1042, 406) -> 4380
# pair (1540, 110) -> 4381
# pair (264, 453) -> 4382
# pair (446, 3064) -> 4383
# pair (358, 689) -> 4384
# pair (1779, 566) -> 4385
# pair (48, 52) -> 4386
# pair (378, 316) -> 4387
# pair (288, 2604) -> 4388
# pair (2013, 355) -> 4389
# pair (1719, 2201) -> 4390
# pair (354, 116) -> 4391
# pair (1614, 2085) -> 4392
# pair (1899, 98) -> 4393
# pair (291, 275) -> 4394
# pair (256, 1025) -> 4395
# pair (2332, 396) -> 4396
# pair (2533, 2278) -> 4397
# pair (975, 403) -> 4398
# pair (101, 366) -> 4399
# pair (2046, 277) -> 4400
# pair (2250, 352) -> 4401
# pair (328, 1871) -> 4402
# pair (397, 810) -> 4403
# pair (523, 114) -> 4404
# pair (353, 1237) -> 4405
# pair (262, 117) -> 4406
# pair (387, 487) -> 4407
# pair (1077, 51) -> 4408
# pair (549, 565) -> 4409
# pair (530, 111) -> 4410
# pair (332, 121) -> 4411
# pair (297, 396) -> 4412
# pair (1534, 426) -> 4413
# pair (552, 1306) -> 4414
# pair (100, 452) -> 4415
# pair (331, 421) -> 4416
# pair (3344, 687) -> 4417
# pair (2082, 614) -> 4418
# pair (109, 121) -> 4419
# pair (105, 844) -> 4420
# pair (264, 1048) -> 4421
# pair (333, 268) -> 4422
# pair (3222, 2950) -> 4423
# pair (1695, 866) -> 4424
# pair (757, 1050) -> 4425
# pair (423, 907) -> 4426
# pair (1492, 3070) -> 4427
# pair (637, 1623) -> 4428
# pair (2244, 354) -> 4429
# pair (908, 289) -> 4430
# pair (341, 275) -> 4431
# pair (1534, 351) -> 4432
# pair (4221, 746) -> 4433
# pair (4433, 2350) -> 4434
# pair (1640, 101) -> 4435
# pair (358, 592) -> 4436
# pair (273, 738) -> 4437
# pair (65, 263) -> 4438
# pair (508, 2085) -> 4439
# pair (499, 562) -> 4440
# pair (440, 1699) -> 4441
# pair (1335, 442) -> 4442
# pair (1797, 3912) -> 4443
# pair (300, 404) -> 4444
# pair (320, 1273) -> 4445
# pair (122, 122) -> 4446
# pair (1490, 352) -> 4447
# pair (341, 266) -> 4448
# pair (269, 273) -> 4449
# pair (114, 657) -> 4450
# pair (2015, 403) -> 4451
# pair (2170, 515) -> 4452
# pair (2310, 497) -> 4453
# pair (343, 2413) -> 4454
# pair (339, 404) -> 4455
# pair (357, 444) -> 4456
# pair (881, 629) -> 4457
# pair (321, 355) -> 4458
# pair (4008, 1527) -> 4459
# pair (97, 101) -> 4460
# pair (1356, 890) -> 4461
# pair (1655, 111) -> 4462
# pair (2404, 287) -> 4463
# pair (70, 4162) -> 4464
# pair (396, 263) -> 4465
# pair (121, 100) -> 4466
# pair (108, 886) -> 4467
# pair (358, 289) -> 4468
# pair (1744, 1465) -> 4469
# pair (256, 952) -> 4470
# pair (340, 1326) -> 4471
# pair (739, 365) -> 4472
# pair (3342, 111) -> 4473
# pair (1473, 291) -> 4474
# pair (1886, 1040) -> 4475
# pair (628, 1133) -> 4476
# pair (2316, 107) -> 4477
# pair (287, 780) -> 4478
# pair (298, 1474) -> 4479
# pair (928, 266) -> 4480
# pair (494, 1657) -> 4481
# pair (628, 115) -> 4482
# pair (2458, 398) -> 4483
# pair (337, 433) -> 4484
# pair (3097, 1142) -> 4485
# pair (114, 103) -> 4486
# pair (271, 439) -> 4487
# pair (1883, 2468) -> 4488
# pair (343, 293) -> 4489
# pair (954, 1252) -> 4490
# pair (668, 296) -> 4491
# pair (423, 395) -> 4492
# pair (3723, 265) -> 4493
# pair (1487, 2401) -> 4494
# pair (707, 121) -> 4495
# pair (518, 3555) -> 4496
# pair (931, 267) -> 4497
# pair (309, 339) -> 4498
# pair (647, 352) -> 4499
# pair (836, 351) -> 4500
# pair (116, 619) -> 4501
# pair (399, 3953) -> 4502
# pair (321, 2296) -> 4503
# pair (264, 470) -> 4504
# pair (905, 120) -> 4505
# pair (269, 689) -> 4506
# pair (99, 345) -> 4507
# pair (3925, 406) -> 4508
# pair (326, 100) -> 4509
# pair (1808, 1968) -> 4510
# pair (2945, 1165) -> 4511
# pair (2366, 392) -> 4512
# pair (76, 1432) -> 4513
# pair (57, 50) -> 4514
# pair (4200, 1449) -> 4515
# pair (1617, 2659) -> 4516
# pair (1761, 1221) -> 4517
# pair (744, 118) -> 4518
# pair (2146, 803) -> 4519
# pair (2526, 1357) -> 4520
# pair (2467, 1212) -> 4521
# pair (681, 117) -> 4522
# pair (1723, 403) -> 4523
# pair (415, 1556) -> 4524
# pair (456, 452) -> 4525
# pair (399, 769) -> 4526
# pair (82, 69) -> 4527
# pair (281, 436) -> 4528
# pair (368, 2045) -> 4529
# pair (3446, 900) -> 4530
# pair (57, 56) -> 4531
# pair (118, 351) -> 4532
# pair (3065, 1507) -> 4533
# pair (653, 338) -> 4534
# pair (3037, 311) -> 4535
# pair (359, 438) -> 4536
# pair (2269, 1297) -> 4537
# pair (3462, 97) -> 4538
# pair (331, 619) -> 4539
# pair (1106, 105) -> 4540
# pair (412, 290) -> 4541
# pair (313, 438) -> 4542
# pair (109, 710) -> 4543
# pair (792, 326) -> 4544
# pair (295, 79) -> 4545
# pair (3861, 868) -> 4546
# pair (116, 567) -> 4547
# pair (531, 53) -> 4548
# pair (898, 1466) -> 4549
# pair (46, 41) -> 4550
# pair (779, 769) -> 4551
# pair (519, 112) -> 4552
# pair (2015, 421) -> 4553
# pair (1747, 97) -> 4554
# pair (685, 1687) -> 4555
# pair (2317, 1404) -> 4556
# pair (1327, 3600) -> 4557
# pair (1923, 364) -> 4558
# pair (723, 48) -> 4559
# pair (57, 52) -> 4560
# pair (343, 900) -> 4561
# pair (86, 267) -> 4562
# pair (1901, 281) -> 4563
# pair (122, 289) -> 4564
# pair (112, 270) -> 4565
# pair (403, 116) -> 4566
# pair (3326, 1192) -> 4567
# pair (825, 350) -> 4568
# pair (108, 457) -> 4569
# pair (332, 310) -> 4570
# pair (1722, 433) -> 4571
# pair (1091, 804) -> 4572
# pair (1887, 108) -> 4573
# pair (812, 55) -> 4574
# pair (2956, 583) -> 4575
# pair (109, 410) -> 4576
# pair (65, 115) -> 4577
# pair (109, 115) -> 4578
# pair (1231, 3946) -> 4579
# pair (102, 1035) -> 4580
# pair (2407, 311) -> 4581
# pair (3515, 3758) -> 4582
# pair (647, 3131) -> 4583
# pair (741, 302) -> 4584
# pair (271, 389) -> 4585
# pair (361, 293) -> 4586
# pair (709, 97) -> 4587
# pair (334, 826) -> 4588
# pair (957, 268) -> 4589
# pair (2904, 320) -> 4590
# pair (3569, 276) -> 4591
# pair (2143, 2627) -> 4592
# pair (114, 118) -> 4593
# pair (454, 268) -> 4594
# pair (962, 920) -> 4595
# pair (1548, 820) -> 4596
# pair (4462, 914) -> 4597
# pair (646, 268) -> 4598
# pair (292, 258) -> 4599
# pair (1601, 718) -> 4600
# pair (469, 55) -> 4601
# pair (260, 366) -> 4602
# pair (259, 404) -> 4603
# pair (341, 332) -> 4604
# pair (3614, 109) -> 4605
# pair (289, 292) -> 4606
# pair (1143, 364) -> 4607
# pair (1293, 284) -> 4608
# pair (3023, 618) -> 4609
# pair (913, 281) -> 4610
# pair (409, 115) -> 4611
# pair (636, 351) -> 4612
# pair (1125, 289) -> 4613
# pair (357, 546) -> 4614
# pair (385, 101) -> 4615
# pair (2051, 285) -> 4616
# pair (313, 270) -> 4617
# pair (2964, 400) -> 4618
# pair (548, 2868) -> 4619
# pair (570, 1713) -> 4620
# pair (1949, 430) -> 4621
# pair (328, 3422) -> 4622
# pair (320, 477) -> 4623
# pair (1074, 641) -> 4624
# pair (1493, 470) -> 4625
# pair (913, 4000) -> 4626
# pair (873, 774) -> 4627
# pair (745, 753) -> 4628
# pair (1188, 4445) -> 4629
# pair (421, 2340) -> 4630
# pair (361, 382) -> 4631
# pair (419, 109) -> 4632
# pair (575, 455) -> 4633
# pair (321, 536) -> 4634
# pair (84, 65) -> 4635
# pair (100, 743) -> 4636
# pair (1962, 1626) -> 4637
# pair (502, 515) -> 4638
# pair (2825, 390) -> 4639
# pair (518, 1265) -> 4640
# pair (812, 49) -> 4641
# pair (2087, 3999) -> 4642
# pair (119, 101) -> 4643
# pair (723, 1565) -> 4644
# pair (1986, 2586) -> 4645
# pair (737, 1561) -> 4646
# pair (1345, 476) -> 4647
# pair (1249, 3483) -> 4648
# pair (348, 1735) -> 4649
# pair (1599, 2193) -> 4650
# pair (1524, 3848) -> 4651
# pair (443, 555) -> 4652
# pair (561, 258) -> 4653
# pair (275, 396) -> 4654
# pair (441, 271) -> 4655
# pair (469, 52) -> 4656
# pair (57, 51) -> 4657
# pair (391, 3666) -> 4658
# pair (735, 3148) -> 4659
# pair (106, 546) -> 4660
# pair (67, 289) -> 4661
# pair (260, 3152) -> 4662
# pair (397, 403) -> 4663
# pair (950, 56) -> 4664
# pair (348, 587) -> 4665
# pair (361, 117) -> 4666
# pair (812, 54) -> 4667
# pair (262, 438) -> 4668
# pair (1105, 718) -> 4669
# pair (3570, 435) -> 4670
# pair (78, 111) -> 4671
# pair (646, 1842) -> 4672
# pair (262, 442) -> 4673
# pair (260, 2607) -> 4674
# pair (1788, 1019) -> 4675
# pair (359, 3277) -> 4676
# pair (1005, 102) -> 4677
# pair (334, 305) -> 4678
# pair (208, 176) -> 4679
# pair (1067, 463) -> 4680
# pair (353, 546) -> 4681
# pair (316, 261) -> 4682
# pair (415, 702) -> 4683
# pair (424, 97) -> 4684
# pair (399, 528) -> 4685
# pair (57, 55) -> 4686
# pair (773, 4164) -> 4687
# pair (100, 407) -> 4688
# pair (437, 740) -> 4689
# pair (1103, 326) -> 4690
# pair (494, 676) -> 4691
# pair (287, 104) -> 4692
# pair (295, 2210) -> 4693
# pair (3774, 2272) -> 4694
# pair (73, 68) -> 4695
# pair (989, 416) -> 4696
# pair (589, 366) -> 4697
# pair (577, 285) -> 4698
# pair (3309, 390) -> 4699
# pair (280, 2437) -> 4700
# pair (396, 445) -> 4701
# pair (2407, 436) -> 4702
# pair (432, 105) -> 4703
# pair (277, 931) -> 4704
# pair (1600, 2111) -> 4705
# pair (504, 112) -> 4706
# pair (195, 129) -> 4707
# pair (1455, 111) -> 4708
# pair (103, 355) -> 4709
# pair (419, 390) -> 4710
# pair (257, 4129) -> 4711
# pair (1578, 289) -> 4712
# pair (1161, 382) -> 4713
# pair (1560, 390) -> 4714
# pair (2143, 2218) -> 4715
# pair (656, 1687) -> 4716
# pair (1698, 610) -> 4717
# pair (835, 4699) -> 4718
# pair (3449, 68) -> 4719
# pair (1008, 293) -> 4720
# pair (360, 706) -> 4721
# pair (1640, 1400) -> 4722
# pair (4033, 332) -> 4723
# pair (382, 281) -> 4724
# pair (3039, 1649) -> 4725
# pair (323, 116) -> 4726
# pair (102, 291) -> 4727
# pair (341, 366) -> 4728
# pair (1085, 267) -> 4729
# pair (812, 53) -> 4730
# pair (1222, 2863) -> 4731
# pair (341, 440) -> 4732
# pair (266, 2322) -> 4733
# pair (317, 3071) -> 4734
# pair (272, 578) -> 4735
# pair (338, 276) -> 4736
# pair (99, 351) -> 4737
# pair (423, 98) -> 4738
# pair (1770, 105) -> 4739
# pair (32, 1055) -> 4740
# pair (3922, 2517) -> 4741
# pair (3018, 293) -> 4742
# pair (1095, 45) -> 4743
# pair (423, 585) -> 4744
# pair (773, 116) -> 4745
# pair (369, 346) -> 4746
# pair (967, 610) -> 4747
# pair (3437, 820) -> 4748
# pair (57, 54) -> 4749
# pair (119, 3442) -> 4750
# pair (2339, 1151) -> 4751
# pair (424, 320) -> 4752
# pair (112, 661) -> 4753
# pair (648, 261) -> 4754
# pair (510, 468) -> 4755
# pair (307, 267) -> 4756
# pair (3255, 312) -> 4757
# pair (118, 273) -> 4758
# pair (343, 121) -> 4759
# pair (99, 1107) -> 4760
# pair (123, 123) -> 4761
# pair (730, 114) -> 4762
# pair (4404, 610) -> 4763
# pair (980, 993) -> 4764
# pair (1059, 902) -> 4765
# pair (1705, 669) -> 4766
# pair (291, 2191) -> 4767
# pair (114, 491) -> 4768
# pair (2071, 803) -> 4769
# pair (512, 2337) -> 4770
# pair (3108, 258) -> 4771
# pair (3197, 551) -> 4772
# pair (1260, 302) -> 4773
# pair (1204, 350) -> 4774
# pair (1278, 318) -> 4775
# pair (288, 1009) -> 4776
# pair (553, 275) -> 4777
# pair (1289, 261) -> 4778
# pair (733, 102) -> 4779
# pair (259, 436) -> 4780
# pair (3178, 1953) -> 4781
# pair (415, 2064) -> 4782
# pair (945, 1624) -> 4783
# pair (69, 80) -> 4784
# pair (328, 286) -> 4785
# pair (1931, 351) -> 4786
# pair (102, 710) -> 4787
# pair (307, 1150) -> 4788
# pair (685, 2598) -> 4789
# pair (424, 73) -> 4790
# pair (1463, 521) -> 4791
# pair (4395, 859) -> 4792
# pair (1629, 545) -> 4793
# pair (3308, 276) -> 4794
# pair (1105, 351) -> 4795
# pair (449, 1784) -> 4796
# pair (2084, 115) -> 4797
# pair (486, 290) -> 4798
# pair (508, 122) -> 4799
# pair (104, 121) -> 4800
# pair (553, 342) -> 4801
# pair (2918, 738) -> 4802
# pair (853, 271) -> 4803
# pair (574, 445) -> 4804
# pair (807, 3451) -> 4805
# pair (646, 265) -> 4806
# pair (888, 312) -> 4807
# pair (1125, 452) -> 4808
# pair (1000, 56) -> 4809
# pair (98, 356) -> 4810
# pair (1141, 1666) -> 4811
# pair (309, 116) -> 4812
# pair (1176, 258) -> 4813
# pair (1072, 97) -> 4814
# pair (1744, 355) -> 4815
# pair (272, 275) -> 4816
# pair (561, 2201) -> 4817
# pair (321, 967) -> 4818
# pair (295, 699) -> 4819
# pair (409, 470) -> 4820
# pair (347, 714) -> 4821
# pair (1119, 858) -> 4822
# pair (283, 1349) -> 4823
# pair (2272, 419) -> 4824
# pair (309, 400) -> 4825
# pair (322, 603) -> 4826
# pair (2005, 1212) -> 4827
# pair (359, 522) -> 4828
# pair (309, 3932) -> 4829
# pair (307, 534) -> 4830
# pair (915, 1256) -> 4831
# pair (1698, 406) -> 4832
# pair (1480, 1828) -> 4833
# pair (1265, 481) -> 4834
# pair (1696, 390) -> 4835
# pair (846, 97) -> 4836
# pair (358, 114) -> 4837
# pair (353, 2727) -> 4838
# pair (297, 68) -> 4839
# pair (1202, 104) -> 4840
# pair (576, 2178) -> 4841
# pair (307, 796) -> 4842
# pair (413, 1705) -> 4843
# pair (339, 110) -> 4844
# pair (2411, 1273) -> 4845
# pair (531, 50) -> 4846
# pair (2722, 4185) -> 4847
# pair (2822, 110) -> 4848
# pair (1488, 479) -> 4849
# pair (72, 923) -> 4850
# pair (331, 886) -> 4851
# pair (3203, 296) -> 4852
# pair (262, 548) -> 4853
# pair (292, 396) -> 4854
# pair (264, 486) -> 4855
# pair (2746, 648) -> 4856
# pair (328, 2361) -> 4857
# pair (724, 2936) -> 4858
# pair (4382, 117) -> 4859
# pair (4381, 380) -> 4860
# pair (1948, 350) -> 4861
# pair (997, 1017) -> 4862
# pair (507, 271) -> 4863
# pair (80, 83) -> 4864
# pair (3507, 4628) -> 4865
# pair (922, 574) -> 4866
# pair (1851, 470) -> 4867
# pair (2747, 258) -> 4868
# pair (1299, 394) -> 4869
# pair (341, 82) -> 4870
# pair (1051, 386) -> 4871
# pair (264, 625) -> 4872
# pair (287, 381) -> 4873
# pair (115, 266) -> 4874
# pair (1728, 445) -> 4875
# pair (103, 265) -> 4876
# pair (268, 104) -> 4877
# pair (328, 705) -> 4878
# pair (569, 2654) -> 4879
# pair (269, 444) -> 4880
# pair (98, 366) -> 4881
# pair (957, 261) -> 4882
# pair (359, 108) -> 4883
# pair (341, 392) -> 4884
# pair (382, 111) -> 4885
# pair (1424, 1247) -> 4886
# pair (3771, 396) -> 4887
# pair (616, 1199) -> 4888
# pair (534, 117) -> 4889
# pair (110, 121) -> 4890
# pair (80, 71) -> 4891
# pair (456, 281) -> 4892
# pair (3044, 2045) -> 4893
# pair (2931, 1256) -> 4894
# pair (100, 121) -> 4895
# pair (369, 468) -> 4896
# pair (275, 1988) -> 4897
# pair (4355, 4736) -> 4898
# pair (323, 3974) -> 4899
# pair (295, 330) -> 4900
# pair (1570, 1941) -> 4901
# pair (317, 3240) -> 4902
# pair (1806, 271) -> 4903
# pair (1004, 4034) -> 4904
# pair (377, 281) -> 4905
# pair (109, 117) -> 4906
# pair (353, 522) -> 4907
# pair (321, 1061) -> 4908
# pair (257, 1475) -> 4909
# pair (541, 122) -> 4910
# pair (3514, 4775) -> 4911
# pair (729, 1273) -> 4912
# pair (1320, 293) -> 4913
# pair (1320, 436) -> 4914
# pair (2514, 276) -> 4915
# pair (1086, 1149) -> 4916
# pair (721, 281) -> 4917
# pair (569, 504) -> 4918
# pair (1140, 374) -> 4919
# pair (438, 488) -> 4920
# pair (343, 2291) -> 4921
# pair (57, 49) -> 4922
# pair (307, 276) -> 4923
# pair (2411, 115) -> 4924
# pair (83, 276) -> 4925
# pair (480, 1226) -> 4926
# pair (577, 302) -> 4927
# pair (773, 292) -> 4928
# pair (438, 107) -> 4929
# pair (531, 56) -> 4930
# pair (582, 426) -> 4931
# pair (2317, 3333) -> 4932
# pair (3324, 866) -> 4933
# pair (322, 1415) -> 4934
# pair (293, 406) -> 4935
# pair (107, 273) -> 4936
# pair (3013, 1025) -> 4937
# pair (37, 509) -> 4938
# pair (343, 310) -> 4939
# pair (767, 1325) -> 4940
# pair (331, 2126) -> 4941
# pair (766, 436) -> 4942
# pair (615, 261) -> 4943
# pair (338, 418) -> 4944
# pair (531, 51) -> 4945
# pair (1610, 302) -> 4946
# pair (1041, 53) -> 4947
# pair (1072, 332) -> 4948
# pair (1182, 852) -> 4949
# pair (1084, 967) -> 4950
# pair (360, 498) -> 4951
# pair (952, 105) -> 4952
# pair (323, 286) -> 4953
# pair (119, 1411) -> 4954
# pair (534, 672) -> 4955
# pair (3375, 3618) -> 4956
# pair (1037, 418) -> 4957
# pair (287, 470) -> 4958
# pair (1963, 73) -> 4959
# pair (1153, 2308) -> 4960
# pair (615, 520) -> 4961
# pair (410, 293) -> 4962
# pair (848, 277) -> 4963
# pair (360, 444) -> 4964
# pair (2151, 121) -> 4965
# pair (415, 102) -> 4966
# pair (368, 3782) -> 4967
# pair (893, 1853) -> 4968
# pair (620, 345) -> 4969
# pair (285, 109) -> 4970
# pair (1390, 1154) -> 4971
# pair (259, 852) -> 4972
# pair (1104, 3353) -> 4973
# pair (2789, 578) -> 4974
# pair (1744, 3351) -> 4975
# pair (83, 101) -> 4976
# pair (2076, 2159) -> 4977
# pair (78, 73) -> 4978
# pair (1548, 2974) -> 4979
# pair (2716, 1116) -> 4980
# pair (111, 743) -> 4981
# pair (3391, 590) -> 4982
# pair (337, 638) -> 4983
# pair (894, 895) -> 4984
# pair (360, 278) -> 4985
# pair (1056, 261) -> 4986
# pair (331, 97) -> 4987
# pair (109, 452) -> 4988
# pair (2348, 772) -> 4989
# pair (1057, 1983) -> 4990
# pair (553, 671) -> 4991
# pair (4326, 4624) -> 4992
# pair (109, 657) -> 4993
# pair (2512, 400) -> 4994
# pair (313, 4719) -> 4995
# pair (982, 952) -> 4996
# pair (1460, 963) -> 4997
# pair (32, 3594) -> 4998
# pair (626, 99) -> 4999

# %% [markdown]
# ### saving the tokenizer
#
# Diferrently from the code executed before (with vocab size 1000), this code uses a dict to store the tokens
# thus, the execution time of this implamentation is faster.
#
# Either way, we sugest you to save the tokenizer, this would let you reuse the trained tokenizer
# and perform the encode and decode functionalities latter on.

# %%
with open('tokenizer5000.pkl', 'wb') as file:
    pickle.dump(tokenizer, file)

# %% [markdown]
# ### Checking the vocabulary
#
# You can check the vocabulary by using the tokenizer.vocab
# the vocab is is stored in a dictionary contioning its token id and its bynary value.

# %%
tokenizer.vocab
# Out:
# {0: b'\x00',
#  1: b'\x01',
#  2: b'\x02',
#  3: b'\x03',
#  4: b'\x04',
#  5: b'\x05',
#  6: b'\x06',
#  7: b'\x07',
#  8: b'\x08',
#  9: b'\t',
#  10: b'\n',
#  11: b'\x0b',
#  12: b'\x0c',
#  13: b'\r',
#  14: b'\x0e',
#  15: b'\x0f',
#  16: b'\x10',
#  17: b'\x11',
#  18: b'\x12',
#  19: b'\x13',
#  20: b'\x14',
#  21: b'\x15',
#  22: b'\x16',
#  23: b'\x17',
#  24: b'\x18',
#  25: b'\x19',
#  26: b'\x1a',
#  27: b'\x1b',
#  28: b'\x1c',
#  29: b'\x1d',
#  30: b'\x1e',
#  31: b'\x1f',
#  32: b' ',
#  33: b'!',
#  34: b'"',
#  35: b'#',
#  36: b'$',
#  37: b'%',
#  38: b'&',
#  39: b"'",
#  40: b'(',
#  41: b')',
#  42: b'*',
#  43: b'+',
#  44: b',',
#  45: b'-',
#  46: b'.',
#  47: b'/',
#  48: b'0',
#  49: b'1',
#  50: b'2',
#  51: b'3',
#  52: b'4',
#  53: b'5',
#  54: b'6',
#  55: b'7',
#  56: b'8',
#  57: b'9',
#  58: b':',
#  59: b';',
#  60: b'<',
#  61: b'=',
#  62: b'>',
#  63: b'?',
#  64: b'@',
#  65: b'A',
#  66: b'B',
#  67: b'C',
#  68: b'D',
#  69: b'E',
#  70: b'F',
#  71: b'G',
#  72: b'H',
#  73: b'I',
#  74: b'J',
#  75: b'K',
#  76: b'L',
#  77: b'M',
#  78: b'N',
#  79: b'O',
#  80: b'P',
#  81: b'Q',
#  82: b'R',
#  83: b'S',
#  84: b'T',
#  85: b'U',
#  86: b'V',
#  87: b'W',
#  88: b'X',
#  89: b'Y',
#  90: b'Z',
#  91: b'[',
#  92: b'\\',
#  93: b']',
#  94: b'^',
#  95: b'_',
#  96: b'`',
#  97: b'a',
#  98: b'b',
#  99: b'c',
#  100: b'd',
#  101: b'e',
#  102: b'f',
#  103: b'g',
#  104: b'h',
#  105: b'i',
#  106: b'j',
#  107: b'k',
#  108: b'l',
#  109: b'm',
#  110: b'n',
#  111: b'o',
#  112: b'p',
#  113: b'q',
#  114: b'r',
#  115: b's',
#  116: b't',
#  117: b'u',
#  118: b'v',
#  119: b'w',
#  120: b'x',
#  121: b'y',
#  122: b'z',
#  123: b'{',
#  124: b'|',
#  125: b'}',
#  126: b'~',
#  127: b'\x7f',
#  128: b'\x80',
#  129: b'\x81',
#  130: b'\x82',
#  131: b'\x83',
#  132: b'\x84',
#  133: b'\x85',
#  134: b'\x86',
#  135: b'\x87',
#  136: b'\x88',
#  137: b'\x89',
#  138: b'\x8a',
#  139: b'\x8b',
#  140: b'\x8c',
#  141: b'\x8d',
#  142: b'\x8e',
#  143: b'\x8f',
#  144: b'\x90',
#  145: b'\x91',
#  146: b'\x92',
#  147: b'\x93',
#  148: b'\x94',
#  149: b'\x95',
#  150: b'\x96',
#  151: b'\x97',
#  152: b'\x98',
#  153: b'\x99',
#  154: b'\x9a',
#  155: b'\x9b',
#  156: b'\x9c',
#  157: b'\x9d',
#  158: b'\x9e',
#  159: b'\x9f',
#  160: b'\xa0',
#  161: b'\xa1',
#  162: b'\xa2',
#  163: b'\xa3',
#  164: b'\xa4',
#  165: b'\xa5',
#  166: b'\xa6',
#  167: b'\xa7',
#  168: b'\xa8',
#  169: b'\xa9',
#  170: b'\xaa',
#  171: b'\xab',
#  172: b'\xac',
#  173: b'\xad',
#  174: b'\xae',
#  175: b'\xaf',
#  176: b'\xb0',
#  177: b'\xb1',
#  178: b'\xb2',
#  179: b'\xb3',
#  180: b'\xb4',
#  181: b'\xb5',
#  182: b'\xb6',
#  183: b'\xb7',
#  184: b'\xb8',
#  185: b'\xb9',
#  186: b'\xba',
#  187: b'\xbb',
#  188: b'\xbc',
#  189: b'\xbd',
#  190: b'\xbe',
#  191: b'\xbf',
#  192: b'\xc0',
#  193: b'\xc1',
#  194: b'\xc2',
#  195: b'\xc3',
#  196: b'\xc4',
#  197: b'\xc5',
#  198: b'\xc6',
#  199: b'\xc7',
#  200: b'\xc8',
#  201: b'\xc9',
#  202: b'\xca',
#  203: b'\xcb',
#  204: b'\xcc',
#  205: b'\xcd',
#  206: b'\xce',
#  207: b'\xcf',
#  208: b'\xd0',
#  209: b'\xd1',
#  210: b'\xd2',
#  211: b'\xd3',
#  212: b'\xd4',
#  213: b'\xd5',
#  214: b'\xd6',
#  215: b'\xd7',
#  216: b'\xd8',
#  217: b'\xd9',
#  218: b'\xda',
#  219: b'\xdb',
#  220: b'\xdc',
#  221: b'\xdd',
#  222: b'\xde',
#  223: b'\xdf',
#  224: b'\xe0',
#  225: b'\xe1',
#  226: b'\xe2',
#  227: b'\xe3',
#  228: b'\xe4',
#  229: b'\xe5',
#  230: b'\xe6',
#  231: b'\xe7',
#  232: b'\xe8',
#  233: b'\xe9',
#  234: b'\xea',
#  235: b'\xeb',
#  236: b'\xec',
#  237: b'\xed',
#  238: b'\xee',
#  239: b'\xef',
#  240: b'\xf0',
#  241: b'\xf1',
#  242: b'\xf2',
#  243: b'\xf3',
#  244: b'\xf4',
#  245: b'\xf5',
#  246: b'\xf6',
#  247: b'\xf7',
#  248: b'\xf8',
#  249: b'\xf9',
#  250: b'\xfa',
#  251: b'\xfb',
#  252: b'\xfc',
#  253: b'\xfd',
#  254: b'\xfe',
#  255: b'\xff',
#  256: b' d',
#  257: b' e',
#  258: b'ra',
#  259: b' a',
#  260: b' de',
#  261: b'os',
#  262: b' p',
#  263: b'nt',
#  264: b' c',
#  265: b'es',
#  266: b'or',
#  267: b'er',
#  268: b'as',
#  269: b' s',
#  270: b'ia',
#  271: b'is',
#  272: b'ad',
#  273: b'in',
#  274: b'\xc3\xa3',
#  275: b're',
#  276: b'\xc3\xa3o',
#  277: b'ma',
#  278: b'ic',
#  279: b' o',
#  280: b' co',
#  281: b'ta',
#  282: b'\xc3\xa7',
#  283: b' n',
#  284: b'ro',
#  285: b'me',
#  286: b'qu',
#  287: b'id',
#  288: b' f',
#  289: b'ar',
#  290: b'nd',
#  291: b'\xc3\xa9',
#  292: b'te',
#  293: b'al',
#  294: b' 1',
#  295: b' C',
#  296: b'io',
#  297: b' A',
#  298: b' do',
#  299: b' |',
#  300: b'\xc3\xad',
#  301: b' u',
#  302: b'to',
#  303: b' qu',
#  304: b' da',
#  305: b'\xc3\xa1',
#  306: b' com',
#  307: b' m',
#  308: b'==',
#  309: b' S',
#  310: b'el',
#  311: b'\xc3\xa7\xc3\xa3o',
#  312: b'nte',
#  313: b' P',
#  314: b' em',
#  315: b'ri',
#  316: b'il',
#  317: b' se',
#  318: b'ol',
#  319: b' *',
#  320: b'an',
#  321: b' M',
#  322: b' t',
#  323: b' E',
#  324: b' que',
#  325: b'en',
#  326: b'ul',
#  327: b' 2',
#  328: b' es',
#  329: b' (',
#  330: b'ara',
#  331: b' re',
#  332: b'on',
#  333: b' v',
#  334: b' l',
#  335: b'ei',
#  336: b' ||',
#  337: b'\xc3\xb3',
#  338: b'ti',
#  339: b'tu',
#  340: b' 19',
#  341: b' B',
#  342: b'gu',
#  343: b' b',
#  344: b' ==',
#  345: b'em',
#  346: b'nc',
#  347: b' no',
#  348: b' ma',
#  349: b' O',
#  350: b'ica',
#  351: b'ado',
#  352: b'ndo',
#  353: b' R',
#  354: b'ha',
#  355: b'ou',
#  356: b'res',
#  357: b' L',
#  358: b' D',
#  359: b' F',
#  360: b' N',
#  361: b' T',
#  362: b' in',
#  363: b'nto',
#  364: b'ns',
#  365: b'do',
#  366: b'us',
#  367: b' um',
#  368: b' na',
#  369: b' I',
#  370: b' g',
#  371: b' uma',
#  372: b' 20',
#  373: b'va',
#  374: b'le',
#  375: b' para',
#  376: b'mp',
#  377: b' por',
#  378: b' G',
#  379: b'idad',
#  380: b'\xc3\xaa',
#  381: b'ent',
#  382: b'ec',
#  383: b' \xc3\xa9',
#  384: b' su',
#  385: b'\xc3\xb5',
#  386: b'oc',
#  387: b' fo',
#  388: b'\xc3\xb5es',
#  389: b'se',
#  390: b'mente',
#  391: b' i',
#  392: b'ras',
#  393: b'\xe2\x80',
#  394: b'ada',
#  395: b'mb',
#  396: b'la',
#  397: b'ig',
#  398: b'ist',
#  399: b' pro',
#  400: b'ho',
#  401: b' \xc3',
#  402: b' os',
#  403: b'na',
#  404: b'de',
#  405: b' as',
#  406: b'idade',
#  407: b'iv',
#  408: b' J',
#  409: b'it',
#  410: b'un',
#  411: b' po',
#  412: b' te',
#  413: b' ex',
#  414: b'da',
#  415: b' des',
#  416: b'iz',
#  417: b' ou',
#  418: b'mo',
#  419: b'ria',
#  420: b'era',
#  421: b'no',
#  422: b' como',
#  423: b' Ca',
#  424: b' V',
#  425: b' dos',
#  426: b'a\xc3\xa7\xc3\xa3o',
#  427: b' H',
#  428: b' \xe2\x80',
#  429: b' pel',
#  430: b'ico',
#  431: b' j',
#  432: b' al',
#  433: b'so',
#  434: b' foi',
#  435: b'ido',
#  436: b'\xc3\xa7\xc3\xb5es',
#  437: b'\xc3\xba',
#  438: b'ac',
#  439: b'ion',
#  440: b'ru',
#  441: b'ita',
#  442: b'ros',
#  443: b'ip',
#  444: b'at',
#  445: b'mento',
#  446: b' ca',
#  447: b'co',
#  448: b' "',
#  449: b' ap',
#  450: b' Es',
#  451: b' =',
#  452: b'ados',
#  453: b'rio',
#  454: b' est',
#  455: b'00',
#  456: b' me',
#  457: b'im',
#  458: b'\xc3\xa9m',
#  459: b'ncia',
#  460: b' h',
#  461: b' ta',
#  462: b'og',
#  463: b'ram',
#  464: b'oria',
#  465: b' U',
#  466: b've',
#  467: b' ===',
#  468: b'nde',
#  469: b' 3',
#  470: b'ores',
#  471: b'he',
#  472: b' mais',
#  473: b'ca',
#  474: b' ao',
#  475: b'if',
#  476: b'ir',
#  477: b'ce',
#  478: b' -',
#  479: b'ter',
#  480: b' ent',
#  481: b'ida',
#  482: b' \xe2\x80\x94',
#  483: b' par',
#  484: b' ser',
#  485: b'\xc3\xa7a',
#  486: b'\xc3\xa2',
#  487: b'ntes',
#  488: b'ial',
#  489: b' \xc3\xa0',
#  490: b'ers',
#  491: b'ina',
#  492: b'eiro',
#  493: b'nos',
#  494: b' cons',
#  495: b'col',
#  496: b'sa',
#  497: b'ista',
#  498: b'ob',
#  499: b'ment',
#  500: b' at',
#  501: b' das',
#  502: b'ur',
#  503: b').',
#  504: b'po',
#  505: b' 199',
#  506: b'du',
#  507: b'tura',
#  508: b' tra',
#  509: b'),',
#  510: b' Co',
#  511: b'ias',
#  512: b' for',
#  513: b' sua',
#  514: b'tiv',
#  515: b'go',
#  516: b' 200',
#  517: b' ter',
#  518: b' con',
#  519: b' to',
#  520: b'ed',
#  521: b'tos',
#  522: b'am',
#  523: b' cont',
#  524: b' n\xc3\xa3o',
#  525: b' Em',
#  526: b' per',
#  527: b' 201',
#  528: b'teg',
#  529: b'\xc3\xads',
#  530: b'ov',
#  531: b' 4',
#  532: b' mu',
#  533: b'ente',
#  534: b'ito',
#  535: b' pr',
#  536: b'ira',
#  537: b'ib',
#  538: b'tic',
#  539: b'eira',
#  540: b'FA',
#  541: b' pa',
#  542: b'tegoria',
#  543: b'nter',
#  544: b'19',
#  545: b'gi',
#  546: b'et',
#  547: b'\xc3\xaancia',
#  548: b'lu',
#  549: b' comp',
#  550: b'mb\xc3\xa9m',
#  551: b'ional',
#  552: b' esp',
#  553: b' ar',
#  554: b' pri',
#  555: b'lo',
#  556: b'\xc3\xa9c',
#  557: b'rasil',
#  558: b' Categoria',
#  559: b'nda',
#  560: b'\xc3\xb4',
#  561: b' \xc3\xa1',
#  562: b'ais',
#  563: b' seu',
#  564: b'dos',
#  565: b'ut',
#  566: b'min',
#  567: b'adas',
#  568: b'ulo',
#  569: b' res',
#  570: b' 18',
#  571: b'ios',
#  572: b' tamb\xc3\xa9m',
#  573: b'ior',
#  574: b'ga',
#  575: b' 5',
#  576: b' Re',
#  577: b' Al',
#  578: b'ura',
#  579: b' out',
#  580: b' K',
#  581: b' W',
#  582: b'pul',
#  583: b'um',
#  584: b'unic',
#  585: b'tal',
#  586: b' No',
#  587: b'pa',
#  588: b' s\xc3\xa3o',
#  589: b' ac',
#  590: b'i\xc3\xa7\xc3\xa3o',
#  591: b' gra',
#  592: b'ez',
#  593: b'bl',
#  594: b' Sa',
#  595: b' entre',
#  596: b' or',
#  597: b'vel',
#  598: b' pela',
#  599: b'tica',
#  600: b'\xc3\xaas',
#  601: b' prime',
#  602: b' |-',
#  603: b'\xc3\xadp',
#  604: b'ando',
#  605: b'color',
#  606: b'gcolor',
#  607: b' pos',
#  608: b'=#',
#  609: b' bgcolor',
#  610: b'\xc3\xa1rio',
#  611: b' esta',
#  612: b' pelo',
#  613: b' mo',
#  614: b'que',
#  615: b' imp',
#  616: b'20',
#  617: b' of',
#  618: b'nta',
#  619: b'ino',
#  620: b'ass',
#  621: b' 6',
#  622: b'cio',
#  623: b' ab',
#  624: b' Pa',
#  625: b'orte',
#  626: b' Mar',
#  627: b' en',
#  628: b'ing',
#  629: b'idos',
#  630: b'man',
#  631: b' segu',
#  632: b'ix',
#  633: b'\xc3\xa1ri',
#  634: b' sob',
#  635: b' Un',
#  636: b'ess',
#  637: b' pre',
#  638: b'gra',
#  639: b'esso',
#  640: b' ha',
#  641: b'imento',
#  642: b' ele',
#  643: b'ch',
#  644: b' Est',
#  645: b' Por',
#  646: b'est',
#  647: b' fu',
#  648: b'ens',
#  649: b' As',
#  650: b' 8',
#  651: b'inc',
#  652: b'inha',
#  653: b' dis',
#  654: b'ja',
#  655: b'titu',
#  656: b' fa',
#  657: b'icos',
#  658: b'FAFA',
#  659: b' ob',
#  660: b' mar',
#  661: b'eu',
#  662: b'vol',
#  663: b'ver',
#  664: b'ire',
#  665: b'unic\xc3\xadp',
#  666: b'gem',
#  667: b' Brasil',
#  668: b'ne',
#  669: b'ima',
#  670: b'pres',
#  671: b'mas',
#  672: b'ral',
#  673: b'\xc3\xb3s',
#  674: b' 7',
#  675: b' Os',
#  676: b'iste',
#  677: b' popul',
#  678: b'pos',
#  679: b' S\xc3\xa3o',
#  680: b'der',
#  681: b' ass',
#  682: b'per',
#  683: b'ran',
#  684: b' anos',
#  685: b' ba',
#  686: b' era',
#  687: b'gues',
#  688: b'gi\xc3\xa3o',
#  689: b'om',
#  690: b'entes',
#  691: b' 198',
#  692: b' mes',
#  693: b'ivers',
#  694: b'erra',
#  695: b' mas',
#  696: b'iro',
#  697: b'tas',
#  698: b' **',
#  699: b'orre',
#  700: b' cidade',
#  701: b'ade',
#  702: b'con',
#  703: b' 0',
#  704: b' mil',
#  705: b'for',
#  706: b'eg',
#  707: b'tor',
#  708: b' fil',
#  709: b'aliz',
#  710: b'icas',
#  711: b' inter',
#  712: b'tiva',
#  713: b'pe',
#  714: b'ite',
#  715: b'hec',
#  716: b' el',
#  717: b'\xc3\xa7o',
#  718: b'aram',
#  719: b'idades',
#  720: b'mentos',
#  721: b' car',
#  722: b'vo',
#  723: b' 9',
#  724: b' an',
#  725: b'bo',
#  726: b'\xc2\xba',
#  727: b'ranc',
#  728: b'iu',
#  729: b' pres',
#  730: b' forma',
#  731: b'bro',
#  732: b'ist\xc3\xb3',
#  733: b' De',
#  734: b'das',
#  735: b' Con',
#  736: b'cia',
#  737: b' nas',
#  738: b'ador',
#  739: b' ro',
#  740: b'mer',
#  741: b' Ma',
#  742: b' Soc',
#  743: b'este',
#  744: b' sobre',
#  745: b'r\xc3\xa1',
#  746: b'NE',
#  747: b'ba',
#  748: b'st',
#  749: b'\xc3\xa9r',
#  750: b'ismo',
#  751: b'gua',
#  752: b'unic\xc3\xadpio',
#  753: b'lia',
#  754: b' pol',
#  755: b' cas',
#  756: b' X',
#  757: b' esc',
#  758: b'je',
#  759: b' Se',
#  760: b' foram',
#  761: b' 197',
#  762: b' nos',
#  763: b' tor',
#  764: b'dia',
#  765: b'ano',
#  766: b' Na',
#  767: b'\xc3\xb4n',
#  768: b' temp',
#  769: b'tes',
#  770: b' cl',
#  771: b' princ',
#  772: b'su',
#  773: b' Ar',
#  774: b'fer',
#  775: b' at\xc3\xa9',
#  776: b'anto',
#  777: b'ie',
#  778: b' produ',
#  779: b'por',
#  780: b'ge',
#  781: b'eito',
#  782: b'AR',
#  783: b' inc',
#  784: b'rea',
#  785: b'via',
#  786: b'rit',
#  787: b'\xc3\xa2n',
#  788: b'\xc3\xa1rios',
#  789: b' Ch',
#  790: b' loc',
#  791: b'ont',
#  792: b' ad',
#  793: b' Gu',
#  794: b'indo',
#  795: b' conc',
#  796: b'\xc3\xadn',
#  797: b'fia',
#  798: b'orro',
#  799: b'ona',
#  800: b'ase',
#  801: b'inal',
#  802: b'tico',
#  803: b'ana',
#  804: b'be',
#  805: b' Ba',
#  806: b'over',
#  807: b' oc',
#  808: b'hos',
#  809: b'uro',
#  810: b'ra\xc3\xa7\xc3\xa3o',
#  811: b' vez',
#  812: b' 196',
#  813: b' hab',
#  814: b'\xe2\x80\x93',
#  815: b' seus',
#  816: b'INE',
#  817: b'iss',
#  818: b'tar',
#  819: b' ho',
#  820: b'enas',
#  821: b' 15',
#  822: b' Su',
#  823: b' cor',
#  824: b' enc',
#  825: b' ind',
#  826: b'iga',
#  827: b' cer',
#  828: b'ipal',
#  829: b' Q',
#  830: b'".',
#  831: b'til',
#  832: b' munic\xc3\xadpio',
#  833: b'\xc3\xa9s',
#  834: b' fre',
#  835: b' ra',
#  836: b' nome',
#  837: b'istas',
#  838: b' Socorro',
#  839: b' Car',
#  840: b' LINE',
#  841: b' LINEAR',
#  842: b'",',
#  843: b'urante',
#  844: b'tivo',
#  845: b' 10',
#  846: b' Jo',
#  847: b' cria',
#  848: b' algu',
#  849: b'ber',
#  850: b'200',
#  851: b'idas',
#  852: b'gre',
#  853: b' le',
#  854: b'bal',
#  855: b' sa',
#  856: b' pa\xc3\xads',
#  857: b'aria',
#  858: b'\xc3\xa7as',
#  859: b'ares',
#  860: b' parte',
#  861: b'\xc3\xbabl',
#  862: b'mos',
#  863: b' Par',
#  864: b'itos',
#  865: b' sub',
#  866: b'les',
#  867: b' 17',
#  868: b'dio',
#  869: b' regi\xc3\xa3o',
#  870: b' qual',
#  871: b' sendo',
#  872: b'cional',
#  873: b' trans',
#  874: b' maior',
#  875: b'ine',
#  876: b'inda',
#  877: b'eral',
#  878: b' Rio',
#  879: b'dem',
#  880: b'ng',
#  881: b' conhec',
#  882: b'ham',
#  883: b' ano',
#  884: b' \xc3\xba',
#  885: b'\xc3\xb3p',
#  886: b'tra',
#  887: b'bu',
#  888: b' Po',
#  889: b' onde',
#  890: b'has',
#  891: b'ard',
#  892: b' Qu',
#  893: b' rela',
#  894: b' cap',
#  895: b'ela',
#  896: b'gos',
#  897: b'vi',
#  898: b' dire',
#  899: b' si',
#  900: b'\xc3\xa1s',
#  901: b' Ro',
#  902: b'adores',
#  903: b' tem',
#  904: b' La',
#  905: b' au',
#  906: b' pol\xc3\xad',
#  907: b'val',
#  908: b'ific',
#  909: b' ins',
#  910: b' \xc3\xa1rea',
#  911: b' Mo',
#  912: b'gan',
#  913: b' lu',
#  914: b'mar',
#  915: b' ver',
#  916: b' 16',
#  917: b'vam',
#  918: b'ign',
#  919: b'ifica',
#  920: b'tro',
#  921: b'km',
#  922: b' lon',
#  923: b'ist\xc3\xb3ria',
#  924: b'nas',
#  925: b' The',
#  926: b'embro',
#  927: b' grande',
#  928: b' col',
#  929: b' desen',
#  930: b'und',
#  931: b'th',
#  932: b' pode',
#  933: b' suas',
#  934: b' 12',
#  935: b' \xe2\x80\x93',
#  936: b' Com',
#  937: b'za',
#  938: b'uma',
#  939: b'tru',
#  940: b'\xc3\xbas',
#  941: b' 13',
#  942: b'oca',
#  943: b' aos',
#  944: b' quando',
#  945: b'\xc3\xadc',
#  946: b'18',
#  947: b'rada',
#  948: b'gar',
#  949: b' faz',
#  950: b' 195',
#  951: b' est\xc3\xa1',
#  952: b'up',
#  953: b' outros',
#  954: b' dist',
#  955: b' mesmo',
#  956: b'pois',
#  957: b'\xc3\xa9ri',
#  958: b' reg',
#  959: b' 1999',
#  960: b' ant',
#  961: b' 14',
#  962: b' Cas',
#  963: b'esa',
#  964: b' contra',
#  965: b'idera',
#  966: b'tual',
#  967: b'end',
#  968: b' primeiro',
#  969: b'iza\xc3\xa7\xc3\xa3o',
#  970: b'emp',
#  971: b'aneiro',
#  972: b'FAFAFA',
#  973: b'inas',
#  974: b'ultura',
#  975: b' gover',
#  976: b' dia',
#  977: b'ncias',
#  978: b'anh',
#  979: b'\xc3\xadcio',
#  980: b' dec',
#  981: b' Para',
#  982: b' rec',
#  983: b' s\xc3\xa9c',
#  984: b'tr',
#  985: b'ves',
#  986: b' inf',
#  987: b'bol',
#  988: b' nov',
#  989: b' Lu',
#  990: b'acional',
#  991: b' popula\xc3\xa7\xc3\xa3o',
#  992: b'ticas',
#  993: b'is\xc3\xa3o',
#  994: b'ju',
#  995: b'ila',
#  996: b'10',
#  997: b' brasil',
#  998: b'ord',
#  999: b'\xc3\xa1ria',
#  ...}

# %% [markdown]
# ### encoding and decoding
#
# Here we will test the tokenizer encode and decode methods
#
# we can see how the tokenizer would split the text when you encode it

# %%
encoded_text = tokenizer.encode("As raízes etimológicas do termo Brasil são de difícil reconstrução.")
for i, value in enumerate(encoded_text):
    display(tokenizer.decode(encoded_text[i:i+1]))
# Out:
# 'As'
# ' ra'
# 'í'
# 'zes'
# ' e'
# 'tim'
# 'ológ'
# 'icas'
# ' do'
# ' termo'
# ' Brasil'
# ' são'
# ' de'
# ' dif'
# 'íc'
# 'il'
# ' recon'
# 'stru'
# 'ção'
# '.'

# %% [markdown]
# We can also use the encode to generate a list of tokens

# %%
text = "gostaria que meu tokenizer conhecesse mais palavras"
display(tokenizer.encode(text))
# Out:
# [896, 4255, 324, 456, 117, 519, 107, 325, 416, 267, 881, 1448, 472, 4512]

# %% [markdown]
# In a similar way, we decode a list of tokens

# %%
display(tokenizer.decode([896,281,419,324,456,117,]))
# Out:
# 'gostaria que meu'

# %% [markdown]
# Finally, we can test if the encoder and decoer are returning the sema set of words.

# %%
display(tokenizer.decode(tokenizer.encode(text)))
# Out:
# 'gostaria que meu tokenizer conhecesse mais palavras'
